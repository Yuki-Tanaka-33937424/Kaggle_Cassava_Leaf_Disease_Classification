# %%
# !pip install pytorch_ranger

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %matplotlib inline

# %%
os.listdir('../input/cassava-leaf-disease-classification/')
# Out:
# ['train_tfrecords',
#  'sample_submission.csv',
#  'test_tfrecords',
#  'label_num_to_disease_map.json',
#  'train_images',
#  'train.csv',
#  'test_images']

# %%
train = pd.read_csv('../input/cassava-leaf-disease-merged/merged.csv')
test = pd.read_csv('../input/cassava-leaf-disease-classification//sample_submission.csv')
label_map = pd.read_json('../input/cassava-leaf-disease-classification/label_num_to_disease_map.json', orient='index')

display(train.head())
display(test.head())
display(label_map)
# Out:
#          image_id  label  source
# 0  1000015157.jpg      0    2020
# 1  1000201771.jpg      3    2020
# 2   100042118.jpg      1    2020
# 3  1000723321.jpg      1    2020
# 4  1000812911.jpg      3    2020
#          image_id  label
# 0  2216849948.jpg      4
#                                      0
# 0       Cassava Bacterial Blight (CBB)
# 1  Cassava Brown Streak Disease (CBSD)
# 2           Cassava Green Mottle (CGM)
# 3         Cassava Mosaic Disease (CMD)
# 4                              Healthy

# %% [markdown]
# ## Directory settings

# %%
OUTPUT_DIR = './'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    
TRAIN_PATH = '../input/cassava-leaf-disease-merged/train'
TEST_PATH = '../input/cassava-leaf-disease-classification/test_images'

# %% [markdown]
# ## CFG

# %%
class CFG:
    debug = False
    apex = False
    print_freq = 20
    num_workers = 4
    model_name = 'tf_efficientnet_b2_ns'
    size = 440
    scheduler = 'CosineAnnealingWarmRestarts'
    loss_train = 'BiTemperedLoss'
    epochs = 10
    T_0 = 10
    lr_1 = 5e-4
    lr_2 = 5e-5
    t1 = 0.9
    t2 = 1.5
    smooth = 1e-2
    min_lr = 1e-6
    batch_size = 16
    weight_decay = 1e-6
    gradient_accumulation_steps = 1
    max_grad_norm = 1000
    seed = 42
    target_size = 5
    target_col = 'label'
    n_fold = 5
    trn_fold = [0, 2]
    train = True
    inference = False
    
if CFG.debug:
    CFG.epochs = 3
    train = train.sample(n=1000, random_state=CFG.seed).reset_index(drop=True)

# %% [markdown]
# ## Library

# %%
import sys
sys.path.append('../input/pytorch-image-models/pytorch-image-models-master')

import os
import math
import time
import random
import shutil
from pathlib import Path
from contextlib import contextmanager
from collections import defaultdict, Counter

import scipy as sp
import numpy as np
import pandas as pd

from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold

from tqdm.auto import tqdm
from functools import partial

import cv2
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam, SGD
import torchvision.models as models
from torch.nn.parameter import Parameter
from torch.utils.data import DataLoader, Dataset
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts, CosineAnnealingLR, ReduceLROnPlateau

sys.path.append('../input/bi-tempered-loss-pytorch')
from bi_tempered_loss import *

# sys.path.append('../input/pytorch-optimizer')
# import torch_optimizer as optim

sys.path.append('../input/pytorch-sam')
from sam import SAM

from albumentations import (
    HorizontalFlip, VerticalFlip, IAAPerspective, ShiftScaleRotate, CLAHE, RandomRotate90,
    Transpose, ShiftScaleRotate, Blur, OpticalDistortion, GridDistortion, HueSaturationValue,
    IAAAdditiveGaussianNoise, GaussNoise, MotionBlur, MedianBlur, IAAPiecewiseAffine, RandomResizedCrop,
    IAASharpen, IAAEmboss, RandomBrightnessContrast, Flip, OneOf, Compose, Normalize, Cutout, CoarseDropout, ShiftScaleRotate, CenterCrop, Resize
)
from albumentations.pytorch import ToTensorV2
from albumentations import ImageOnlyTransform

import timm

import warnings 
warnings.filterwarnings('ignore')

if CFG.apex:
    from apex import amp

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Utils

# %%
def get_score(y_true, y_pred):
    return accuracy_score(y_true, y_pred)

@contextmanager
def timer(name):
    t0 = time.time()
    LOGGER.info(f'[{name}] start')
    yield
    LOGGER.info(f'[{name}] done in {time.time() - t0:.0f}')
    
def init_logger(log_file=OUTPUT_DIR+'train.log'):
    from logging import getLogger, INFO, FileHandler,  Formatter,  StreamHandler
    logger = getLogger(__name__)
    logger.setLevel(INFO)
    handler1 = StreamHandler()
    handler1.setFormatter(Formatter("%(message)s"))
    handler2 = FileHandler(filename=log_file)
    handler2.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler1)
    logger.addHandler(handler2)
    return logger

LOGGER = init_logger()

def seed_torch(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

seed_torch(seed=CFG.seed)

# %% [markdown]
# ## CV split

# %%
folds = train.copy()
Fold = StratifiedKFold(n_splits=CFG.n_fold, shuffle=True, random_state=CFG.seed)
for n, (train_index, val_index) in enumerate(Fold.split(folds, folds[CFG.target_col])):
    folds.loc[val_index, 'fold'] = int(n)
folds['fold'] = folds['fold'].astype(int)
print(folds.groupby(['fold', CFG.target_col]).size())
# Out:
# fold  label
# 0     0         299
#       1         695
#       2         604
#       3        3092
#       4         578
# 1     0         299
#       1         695
#       2         604
#       3        3092
#       4         578
# 2     0         298
#       1         695
#       2         603
#       3        3093
#       4         578
# 3     0         298
#       1         695
#       2         603
#       3        3093
#       4         578
# 4     0         298
#       1         696
#       2         603
#       3        3092
#       4         578
# dtype: int64

# %% [markdown]
# ## Dataset

# %%
class TrainDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.file_names = df['image_id'].values
        self.labels = df['label'].values
#         self.labels = pd.get_dummies(df['label']).values  # One Hot Encoding
        self.transform = transform
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        file_name = self.file_names[idx]
        file_path = f'{TRAIN_PATH}/{file_name}'
        image = cv2.imread(file_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']
        label = torch.tensor(self.labels[idx]).long()
        return image, label
    
class TestDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.file_names = df['image_id'].values
        self.transform = transform
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        file_name = self.file_names[idx]
        file_path = f'{TEST_PATH}/{file_name}'
        image = cv2.imread(file_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']
        return image

# %%
# train_dataset = TrainDataset(train, transform=None)

# for i in range(1):
#     image, label = train_dataset[i]
#     plt.imshow(image)
#     plt.title(f'label: {label}')
#     plt.show()

# %% [markdown]
# ## Transforms

# %%
def get_transforms(*, data):
    
    if data == 'train':
        return Compose([
            RandomResizedCrop(CFG.size, CFG.size), 
            Transpose(p=0.5), 
            HorizontalFlip(p=0.5), 
            VerticalFlip(p=0.5), 
            ShiftScaleRotate(p=0.5), 
            HueSaturationValue(hue_shift_limit=0.2, sat_shift_limit=0.2, val_shift_limit=0.2, p=0.5), 
            RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), p=0.5), 
            Normalize(
                mean=[0.485, 0.456, 0.406], 
                std=[0.229, 0.224, 0.225], 
            ), 
            ToTensorV2(),
        ])
    
    elif data == 'valid':
        return Compose([
            Resize(CFG.size, CFG.size), 
            Normalize(
                mean=[0.485, 0.456, 0.406], 
                std=[0.229, 0.224, 0.225], 
            ), 
            ToTensorV2(),
        ])

# %%
# train_dataset = TrainDataset(train, transform=get_transforms(data='train'))

# for i in range(1):
#     image, label = train_dataset[i]
#     plt.imshow(image[0])
#     plt.title(f'label: {label}')
#     plt.show()

# %% [markdown]
# ## MODEL

# %%
class CustomEfficientNetB2ns(nn.Module):
    def __init__(self, model_name='tf_efficientnet_b2_ns', pretrained=False):
        super().__init__()
        self.model = timm.create_model(model_name, pretrained=pretrained)
        n_features = self.model.classifier.in_features
        self.model.classifier = nn.Linear(n_features, CFG.target_size)
        
    def forward(self, x):
        x = self.model(x)
        return x

# %%
# model = CustomEfficientNetB2ns(model_name=CFG.model_name, pretrained=False)
# train_dataset = TrainDataset(train, transform=get_transforms(data='train'))
# train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, 
#                           num_workers=4, pin_memory=True, drop_last=True)

# for image, label in train_loader:
#     print(image.size())
#     output = model(image)
#     print(output)
#     break

# %% [markdown]
# ## Loss Functions

# %%
# ====================================================
# Label Smoothing
# ====================================================
class LabelSmoothingLoss(nn.Module): 
    def __init__(self, classes=5, smoothing=0.0, dim=-1): 
        super(LabelSmoothingLoss, self).__init__() 
        self.confidence = 1.0 - smoothing 
        self.smoothing = smoothing 
        self.cls = classes 
        self.dim = dim 
    def forward(self, pred, target): 
        pred = pred.log_softmax(dim=self.dim) 
        with torch.no_grad():
            true_dist = torch.zeros_like(pred) 
            true_dist.fill_(self.smoothing / (self.cls - 1)) 
            true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence) 
        return torch.mean(torch.sum(-true_dist * pred, dim=self.dim))

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduce=True):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduce = reduce

    def forward(self, inputs, targets):
        BCE_loss = nn.CrossEntropyLoss()(inputs, targets)

        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1-pt)**self.gamma * BCE_loss

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss

# %%
class FocalCosineLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, xent=.1):
        super(FocalCosineLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

        self.xent = xent

        self.y = torch.Tensor([1]).cuda()

    def forward(self, input, target, reduction="mean"):
        cosine_loss = F.cosine_embedding_loss(input, F.one_hot(target, num_classes=input.size(-1)), self.y, reduction=reduction)

        cent_loss = F.cross_entropy(F.normalize(input), target, reduce=False)
        pt = torch.exp(-cent_loss)
        focal_loss = self.alpha * (1-pt)**self.gamma * cent_loss

        if reduction == "mean":
            focal_loss = torch.mean(focal_loss)

        return cosine_loss + self.xent * focal_loss

# %%
class SymmetricCrossEntropy(nn.Module):

    def __init__(self, alpha=0.1, beta=1.0, num_classes=5):
        super(SymmetricCrossEntropy, self).__init__()
        self.alpha = alpha
        self.beta = beta
        self.num_classes = num_classes

    def forward(self, logits, targets, reduction='mean'):
        onehot_targets = torch.eye(self.num_classes)[targets].cuda()
        ce_loss = F.cross_entropy(logits, targets, reduction=reduction)
        rce_loss = (-onehot_targets*logits.softmax(1).clamp(1e-7, 1.0).log()).sum(1)
        if reduction == 'mean':
            rce_loss = rce_loss.mean()
        elif reduction == 'sum':
            rce_loss = rce_loss.sum()
        return self.alpha * ce_loss + self.beta * rce_loss

# %%
def log_t(u, t):
    """Compute log_t for `u'."""
    if t==1.0:
        return u.log()
    else:
        return (u.pow(1.0 - t) - 1.0) / (1.0 - t)

def exp_t(u, t):
    """Compute exp_t for `u'."""
    if t==1:
        return u.exp()
    else:
        return (1.0 + (1.0-t)*u).relu().pow(1.0 / (1.0 - t))

def compute_normalization_fixed_point(activations, t, num_iters):

    """Returns the normalization value for each example (t > 1.0).
    Args:
      activations: A multi-dimensional tensor with last dimension `num_classes`.
      t: Temperature 2 (> 1.0 for tail heaviness).
      num_iters: Number of iterations to run the method.
    Return: A tensor of same shape as activation with the last dimension being 1.
    """
    mu, _ = torch.max(activations, -1, keepdim=True)
    normalized_activations_step_0 = activations - mu

    normalized_activations = normalized_activations_step_0

    for _ in range(num_iters):
        logt_partition = torch.sum(
                exp_t(normalized_activations, t), -1, keepdim=True)
        normalized_activations = normalized_activations_step_0 * \
                logt_partition.pow(1.0-t)

    logt_partition = torch.sum(
            exp_t(normalized_activations, t), -1, keepdim=True)
    normalization_constants = - log_t(1.0 / logt_partition, t) + mu

    return normalization_constants

def compute_normalization_binary_search(activations, t, num_iters):

    """Returns the normalization value for each example (t < 1.0).
    Args:
      activations: A multi-dimensional tensor with last dimension `num_classes`.
      t: Temperature 2 (< 1.0 for finite support).
      num_iters: Number of iterations to run the method.
    Return: A tensor of same rank as activation with the last dimension being 1.
    """

    mu, _ = torch.max(activations, -1, keepdim=True)
    normalized_activations = activations - mu

    effective_dim = \
        torch.sum(
                (normalized_activations > -1.0 / (1.0-t)).to(torch.int32),
            dim=-1, keepdim=True).to(activations.dtype)

    shape_partition = activations.shape[:-1] + (1,)
    lower = torch.zeros(shape_partition, dtype=activations.dtype, device=activations.device)
    upper = -log_t(1.0/effective_dim, t) * torch.ones_like(lower)

    for _ in range(num_iters):
        logt_partition = (upper + lower)/2.0
        sum_probs = torch.sum(
                exp_t(normalized_activations - logt_partition, t),
                dim=-1, keepdim=True)
        update = (sum_probs < 1.0).to(activations.dtype)
        lower = torch.reshape(
                lower * update + (1.0-update) * logt_partition,
                shape_partition)
        upper = torch.reshape(
                upper * (1.0 - update) + update * logt_partition,
                shape_partition)

    logt_partition = (upper + lower)/2.0
    return logt_partition + mu

class ComputeNormalization(torch.autograd.Function):
    """
    Class implementing custom backward pass for compute_normalization. See compute_normalization.
    """
    @staticmethod
    def forward(ctx, activations, t, num_iters):
        if t < 1.0:
            normalization_constants = compute_normalization_binary_search(activations, t, num_iters)
        else:
            normalization_constants = compute_normalization_fixed_point(activations, t, num_iters)

        ctx.save_for_backward(activations, normalization_constants)
        ctx.t=t
        return normalization_constants

    @staticmethod
    def backward(ctx, grad_output):
        activations, normalization_constants = ctx.saved_tensors
        t = ctx.t
        normalized_activations = activations - normalization_constants 
        probabilities = exp_t(normalized_activations, t)
        escorts = probabilities.pow(t)
        escorts = escorts / escorts.sum(dim=-1, keepdim=True)
        grad_input = escorts * grad_output
        
        return grad_input, None, None

def compute_normalization(activations, t, num_iters=5):
    """Returns the normalization value for each example. 
    Backward pass is implemented.
    Args:
      activations: A multi-dimensional tensor with last dimension `num_classes`.
      t: Temperature 2 (> 1.0 for tail heaviness, < 1.0 for finite support).
      num_iters: Number of iterations to run the method.
    Return: A tensor of same rank as activation with the last dimension being 1.
    """
    return ComputeNormalization.apply(activations, t, num_iters)

def tempered_sigmoid(activations, t, num_iters = 5):
    """Tempered sigmoid function.
    Args:
      activations: Activations for the positive class for binary classification.
      t: Temperature tensor > 0.0.
      num_iters: Number of iterations to run the method.
    Returns:
      A probabilities tensor.
    """
    internal_activations = torch.stack([activations,
        torch.zeros_like(activations)],
        dim=-1)
    internal_probabilities = tempered_softmax(internal_activations, t, num_iters)
    return internal_probabilities[..., 0]


def tempered_softmax(activations, t, num_iters=5):
    """Tempered softmax function.
    Args:
      activations: A multi-dimensional tensor with last dimension `num_classes`.
      t: Temperature > 1.0.
      num_iters: Number of iterations to run the method.
    Returns:
      A probabilities tensor.
    """
    if t == 1.0:
        return activations.softmax(dim=-1)

    normalization_constants = compute_normalization(activations, t, num_iters)
    return exp_t(activations - normalization_constants, t)

def bi_tempered_binary_logistic_loss(activations,
        labels,
        t1,
        t2,
        label_smoothing = 0.0,
        num_iters=5,
        reduction='mean'):

    """Bi-Tempered binary logistic loss.
    Args:
      activations: A tensor containing activations for class 1.
      labels: A tensor with shape as activations, containing probabilities for class 1
      t1: Temperature 1 (< 1.0 for boundedness).
      t2: Temperature 2 (> 1.0 for tail heaviness, < 1.0 for finite support).
      label_smoothing: Label smoothing
      num_iters: Number of iterations to run the method.
    Returns:
      A loss tensor.
    """
    internal_activations = torch.stack([activations,
        torch.zeros_like(activations)],
        dim=-1)
    internal_labels = torch.stack([labels.to(activations.dtype),
        1.0 - labels.to(activations.dtype)],
        dim=-1)
    return bi_tempered_logistic_loss(internal_activations, 
            internal_labels,
            t1,
            t2,
            label_smoothing = label_smoothing,
            num_iters = num_iters,
            reduction = reduction)

def bi_tempered_logistic_loss(activations,
        labels,
        t1,
        t2,
        label_smoothing=0.0,
        num_iters=5,
        reduction = 'mean'):

    """Bi-Tempered Logistic Loss.
    Args:
      activations: A multi-dimensional tensor with last dimension `num_classes`.
      labels: A tensor with shape and dtype as activations (onehot), 
        or a long tensor of one dimension less than activations (pytorch standard)
      t1: Temperature 1 (< 1.0 for boundedness).
      t2: Temperature 2 (> 1.0 for tail heaviness, < 1.0 for finite support).
      label_smoothing: Label smoothing parameter between [0, 1). Default 0.0.
      num_iters: Number of iterations to run the method. Default 5.
      reduction: ``'none'`` | ``'mean'`` | ``'sum'``. Default ``'mean'``.
        ``'none'``: No reduction is applied, return shape is shape of
        activations without the last dimension.
        ``'mean'``: Loss is averaged over minibatch. Return shape (1,)
        ``'sum'``: Loss is summed over minibatch. Return shape (1,)
    Returns:
      A loss tensor.
    """

    if len(labels.shape)<len(activations.shape): #not one-hot
        labels_onehot = torch.zeros_like(activations)
        labels_onehot.scatter_(1, labels[..., None], 1)
    else:
        labels_onehot = labels

    if label_smoothing > 0:
        num_classes = labels_onehot.shape[-1]
        labels_onehot = ( 1 - label_smoothing * num_classes / (num_classes - 1) ) \
                * labels_onehot + \
                label_smoothing / (num_classes - 1)

    probabilities = tempered_softmax(activations, t2, num_iters)

    loss_values = labels_onehot * log_t(labels_onehot + 1e-10, t1) \
            - labels_onehot * log_t(probabilities, t1) \
            - labels_onehot.pow(2.0 - t1) / (2.0 - t1) \
            + probabilities.pow(2.0 - t1) / (2.0 - t1)
    loss_values = loss_values.sum(dim = -1) #sum over classes

    if reduction == 'none':
        return loss_values
    if reduction == 'sum':
        return loss_values.sum()
    if reduction == 'mean':
        return loss_values.mean()

# %%
class BiTemperedLogisticLoss(nn.Module): 
    def __init__(self, t1, t2, smoothing=0.0): 
        super(BiTemperedLogisticLoss, self).__init__() 
        self.t1 = t1
        self.t2 = t2
        self.smoothing = smoothing
    def forward(self, logit_label, truth_label):
        loss_label = bi_tempered_logistic_loss(
            logit_label, truth_label,
            t1=self.t1, t2=self.t2,
            label_smoothing=self.smoothing,
            reduction='none'
        )
        
        loss_label = loss_label.mean()
        return loss_label

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()
        
    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0
        
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
        
def asMinutes(s):
    """秒を分に変換する関数"""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """経過時間の測定と終了時間の予測を行う関数
    Parameters
    ----------
    since : float
        実験を始めた時刻
    percent : float
        実験が進んだ割合
        
    Returns
    -------
    s : 経過時間
    re : 終了までの時間の予測
    """
    now = time.time()
    s = now - since  # 経過時間の測定
    es = s / percent  # 終了時間の予測
    re = es - s  # 残り時間の予想
    return '%s (remain %s)' % (asMinutes(s), asMinutes(re))

def train_fn(train_loader, model, loss_train, loss_metric, optimizer, epoch, shechduler, device):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    scores = AverageMeter()
    # switch to train mode
    model.train()
    start = end = time.time()
    global_step = 0
    for step, (images, labels) in enumerate(train_loader):
        # measure data loading time
        data_time.update(time.time() - end)
        images = images.to(device)
        labels = labels.to(device)
        batch_size = labels.size(0)
        y_preds = model(images)
        metric = loss_metric(y_preds, labels)
        loss = loss_train(y_preds, labels)
        # record loss
        losses.update(metric.item(), batch_size)
        if CFG.gradient_accumulation_steps > 1:
            loss = loss / CFG.gradient_accumulation_steps
        if CFG.apex:
            with amp.scale_loss(loss, optimizer) as scaled_loss:
                scaled_loss.backward()
        else: 
            loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), CFG.max_grad_norm)
        if (step + 1) % CFG.gradient_accumulation_steps == 0:
            optimizer.first_step(zero_grad=True)
#             optimizer.zero_grad()
            global_step += 1
        # measure elapsed time
        loss_train(model(images), labels).backward()
#         loss = torch.mean(loss)
#         loss.backward()
        optimizer.second_step(zero_grad=True)
        
        batch_time.update(time.time() - end)
        end = time.time()
        if step % CFG.print_freq == 0 or step == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}]'
                  'Data {data_time.val:.3f} ({data_time.avg:.3f})'
                  'Elapsed {remain:s}' 
                  'Loss: {loss.val:.4f}({loss.avg:.4f})' 
                  'Grad: {grad_norm:.4f}  '
                  .format(epoch+1, step, len(train_loader), batch_time=batch_time, 
                          data_time=data_time, loss=losses, 
                          remain=timeSince(start, float(step+1)/len(train_loader)), 
                          grad_norm=grad_norm))
    return losses.avg

def valid_fn(valid_loader, model, loss_metric, device):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    scores = AverageMeter()
    # switch to evaluation mode
    model.eval()
    preds = []
    start = end = time.time()
    for step, (images, labels) in enumerate(valid_loader):
        # measure data loading time
        data_time.update(time.time() - end)
        images = images.to(device)
        labels = labels.to(device)
        batch_size = labels.size(0)
        # compute loss
        with torch.no_grad():
            y_preds = model(images)
        loss = loss_metric(y_preds, labels)
        losses.update(loss.item(), batch_size)
        # record accuracy
        preds.append(y_preds.softmax(1).to('cpu').numpy())
        if CFG.gradient_accumulation_steps > 1:
            loss = loss / CFG.gradient_accumulation_steps
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        if step % CFG.print_freq == 0 or step == (len(valid_loader)-1):
            print('EVAL: [{0}/{1}] '
                  'Data {data_time.val:.3f} ({data_time.avg:.3f}) '
                  'Elapsed {remain:s} '
                  'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                  .format(
                   step, len(valid_loader), batch_time=batch_time,
                   data_time=data_time, loss=losses,
                   remain=timeSince(start, float(step+1)/len(valid_loader)),
                   ))
            
    predictions = np.concatenate(preds)
    return losses.avg, predictions

def inference(model, states, test_loader, device):
    model.to(device)
    tk0 = tqdm(enumerate(test_loader), total=len(test_loader))
    probs = []
    for i, (images) in tk0:
        images = images.to(device)
        avgpreds = []
        for state in states:
            model.load_state_dict(state['model'])
            model.eval()
            with torch.no_grad():
                y_preds = model(images)
            avg_preds.append(y_preds.softmax(1).to('cpu').numpy())
        avg_preds = np.mean(avg_preds, axis=0)
        probs.append(avg_preds)
    probs = np.concatenate(probs)
    return probs

# %% [markdown]
# ## Train loop

# %%
# ======================================================
# Train loop
# ======================================================

def train_loop(folds, fold):
    
    seed_torch(seed=CFG.seed)    
    
    LOGGER.info(f'========== fold: {fold} training ============')
    
    # ======================================================
    # loader
    # ======================================================
    trn_idx = folds[folds['fold'] != fold].index
    val_idx = folds[folds['fold'] == fold].index
    
    train_folds = folds.loc[trn_idx].reset_index(drop=True)
    valid_folds = folds.loc[val_idx].reset_index(drop=True)
    
    train_dataset = TrainDataset(train_folds, 
                                 transform=get_transforms(data='train'))
    valid_dataset = TrainDataset(valid_folds, 
                                 transform=get_transforms(data='valid'))
    
    train_loader = DataLoader(train_dataset, 
                              batch_size=CFG.batch_size, 
                              shuffle=True, 
                              num_workers=CFG.num_workers, 
                              pin_memory=True, 
                              drop_last=False)
    valid_loader = DataLoader(valid_dataset, 
                              batch_size=CFG.batch_size, 
                              shuffle=False, 
                              num_workers=CFG.num_workers, 
                              pin_memory=True, 
                              drop_last=False)
    
    # ===============================================
    # scheduler
    # ===============================================
    def get_scheduler(optimizer):
        if CFG.scheduler=='ReduceLROnPlateau':
            scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=CFG.factor, patience=CFG.patience, verbose=True, eps=CFG.eps)
        elif CFG.scheduler=='CosineAnnealingLR':
            scheduler = CosineAnnealingLR(optimizer, T_max=CFG.T_max, eta_min=CFG.min_lr, last_epoch=-1)
        elif CFG.scheduler=='CosineAnnealingWarmRestarts':
            scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=CFG.T_0, T_mult=1, eta_min=CFG.min_lr, last_epoch=-1)
        return scheduler
    
    # ===============================================
    # model & optimizer
    # ===============================================
    model = CustomEfficientNetB2ns(CFG.model_name, pretrained=True)
    
    # 最初の3epochはclassifier層以外全て凍結する。
    for name, param in model.model.named_parameters():
        if 'classifier' not in name:
            param.requires_grad=False
    
    model.to(device)
    
    base_optimizer = Adam
    optimizer = SAM(model.parameters(), base_optimizer, lr=CFG.lr_1, weight_decay=CFG.weight_decay, amsgrad=False)
    
    scheduler = get_scheduler(optimizer)
    
    # ===============================================
    # apex 
    # ===============================================
    if CFG.apex:
        model.optimizer = amp.initialize(model, optimizer, opt_level='O1', verbosity=0)
        
    # ===============================================
    # loop
    # ===============================================
    def get_loss_train():
        if CFG.loss_train == 'CrossEntropyLoss':
            loss_train = nn.CrossEntropyLoss()
        elif CFG.loss_train == 'LabelSmoothing':
            loss_train = LabelSmoothingLoss(classes=CFG.target_size, smoothing=CFG.smooth)
        elif CFG.loss_train == 'FocalLoss':
            loss_train = FocalLoss().to(device)
        elif CFG.loss_train == 'FocalCosineLoss':
            loss_train = FocalCosineLoss()
        elif CFG.loss_train == 'SymmetricCrossEntropyLoss':
            loss_train = SymmetricCrossEntropy().to(device)
        elif CFG.loss_train == 'BiTemperedLoss':
            loss_train = BiTemperedLogisticLoss(t1=CFG.t1, t2=CFG.t2, smoothing=CFG.smooth)
        return loss_train
    
    loss_train = get_loss_train()
    LOGGER.info(f'loss_train: {loss_train}')
    loss_metric = nn.CrossEntropyLoss()
    
    best_score = 0.
    best_loss = np.inf
    
    for epoch in range(CFG.epochs):
        
        start_time = time.time()
        
        if epoch == 1:
            
            # 2epoch目に重みを全て解凍する
            for param in model.model.parameters():
                param.requires_grad = True
                
            # 学習率を4e-3から4e-4に落とす
            base_optimizer = Adam
            optimizer = SAM(model.parameters(), base_optimizer, lr=CFG.lr_2, weight_decay=CFG.weight_decay, amsgrad=False)
            scheduler = get_scheduler(optimizer)

            LOGGER.info('requires_grad of all parameters are unlocked')
            
        
        # train
        avg_loss = train_fn(train_loader, model, loss_train, loss_metric, optimizer, epoch, scheduler, device)
        
        # eval
        avg_val_loss, preds = valid_fn(valid_loader, model, loss_metric, device)
        valid_labels = valid_folds[CFG.target_col].values
        
        if isinstance(scheduler, ReduceLROnPlateau):
            scheduler.step(avg_val_loss)
        elif isinstance(scheduler, CosineAnnealingLR):
            scheduler.step()
        elif isinstance(scheduler, CosineAnnealingWarmRestarts):
            scheduler.step()
        
        # scoring
        score = get_score(valid_labels, preds.argmax(1))
        
        elapsed = time.time() - start_time
        
        LOGGER.info(f'Epoch {epoch+1} - avg_train_loss: {avg_loss:.4f} avg_val_loss: {avg_val_loss:.4f} time: {elapsed:.0f}s')
        LOGGER.info(f'Epoch {epoch+1} - Accuracy: {score}')
        
        if score > best_score:
            best_score = score
            LOGGER.info(f'Epoch {epoch+1} - Save Best Score: {best_score:.4f} Model')
            torch.save({'model': model.state_dict(), 
                        'preds': preds}, 
                        OUTPUT_DIR+f'{CFG.model_name}_fold{fold}_best.pth')
            
        # inference用に全て保存しておく        
        torch.save({'model': model.state_dict()}, OUTPUT_DIR+f'{CFG.model_name}_fold{fold}_epoch{epoch+1}.pth')
    
    check_point = torch.load(OUTPUT_DIR+f'{CFG.model_name}_fold{fold}_best.pth')
    valid_folds[[str(c) for c in range(5)]] = check_point['preds']
    valid_folds['preds'] = check_point['preds'].argmax(1)
    
    return valid_folds

# %%
# ====================================================
# main
# ====================================================
def main():
    
    """
    Prepare: 1.train 2.test 3.submission 4.folds
    """
    
    def get_result(result_df):
        preds = result_df['preds'].values
        labels = result_df[CFG.target_col].values
        score = get_score(labels, preds)
        LOGGER.info(f'Score: {score:<.5f}')
        
    if CFG.train:
        # train
        oof_df = pd.DataFrame()
        for fold in range(CFG.n_fold):
            if fold in CFG.trn_fold:
                _oof_df = train_loop(folds, fold)
                oof_df = pd.concat([oof_df, _oof_df])
                LOGGER.info(f'=============== fold: {fold} result ================')
                get_result(_oof_df)
                
                
        # CV result
        LOGGER.info(f'============ CV ============')
        get_result(oof_df)
        # save result
        oof_df.to_csv(OUTPUT_DIR+'oof_df.csv', index=False)
        
    if CFG.inference:
        # inference
        model = CustomEfficientNetB2ns(CFG.model_name, pretrained=False)
        states = [torch.load(OUTPUT_DIR+f'{CFG.model_name}_fold{fold}_best.pth') for fold in CFG.trn_fold]
        test_dataset = TestDataset(test, batch_size=CFG.batch_size, shuffle=False, pin_memory=True)
        predictions = inference(model, states, test_loader, device)
        # submission
        test['label'] = predictions.argmax(1)
        test[['image_id', 'label']].to_csv(OUTPUT_DIR+'submission.csv', index=False)

# %%
LOGGER.info(f'used device: {device}')
# Out:
# used device: cuda

# %%
if __name__ == '__main__':
    main()
# Out:
# ========== fold: 0 training ============
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/tf_efficientnet_b2_ns-00306e48.pth" to /root/.cache/torch/hub/checkpoints/tf_efficientnet_b2_ns-00306e48.pth
# loss_train: BiTemperedLogisticLoss()
# Epoch: [1][0/1317]Data 2.051 (2.051)Elapsed 0m 3s (remain 82m 2s)Loss: 1.6490(1.6490)Grad: 0.6519
# Epoch: [1][20/1317]Data 0.000 (0.101)Elapsed 0m 9s (remain 9m 24s)Loss: 1.3508(1.4228)Grad: 0.5230
# Epoch: [1][40/1317]Data 0.000 (0.052)Elapsed 0m 15s (remain 8m 1s)Loss: 1.5710(1.3855)Grad: 0.4310
# Epoch: [1][60/1317]Data 0.000 (0.036)Elapsed 0m 20s (remain 7m 10s)Loss: 0.8743(1.4140)Grad: 0.4157
# Epoch: [1][80/1317]Data 0.000 (0.027)Elapsed 0m 26s (remain 6m 49s)Loss: 1.0298(1.4214)Grad: 0.4736
# Epoch: [1][100/1317]Data 0.000 (0.027)Elapsed 0m 32s (remain 6m 35s)Loss: 0.5246(1.3964)Grad: 0.4674
# Epoch: [1][120/1317]Data 0.001 (0.025)Elapsed 0m 39s (remain 6m 32s)Loss: 1.9470(1.3889)Grad: 0.3552
# Epoch: [1][140/1317]Data 0.000 (0.027)Elapsed 0m 45s (remain 6m 22s)Loss: 1.8895(1.4030)Grad: 0.4727
# Epoch: [1][160/1317]Data 0.000 (0.025)Elapsed 0m 51s (remain 6m 12s)Loss: 2.1853(1.3904)Grad: 0.4707
# Epoch: [1][180/1317]Data 0.010 (0.026)Elapsed 0m 58s (remain 6m 5s)Loss: 1.1053(1.3713)Grad: 0.3786
# Epoch: [1][200/1317]Data 0.001 (0.025)Elapsed 1m 3s (remain 5m 55s)Loss: 1.1510(1.3578)Grad: 0.3662
# Epoch: [1][220/1317]Data 0.000 (0.026)Elapsed 1m 10s (remain 5m 51s)Loss: 1.1767(1.3497)Grad: 0.3724
# Epoch: [1][240/1317]Data 0.003 (0.028)Elapsed 1m 16s (remain 5m 43s)Loss: 2.3868(1.3528)Grad: 0.4496
# Epoch: [1][260/1317]Data 0.000 (0.026)Elapsed 1m 23s (remain 5m 36s)Loss: 0.9013(1.3490)Grad: 0.4128
# Epoch: [1][280/1317]Data 0.000 (0.026)Elapsed 1m 29s (remain 5m 28s)Loss: 0.7605(1.3298)Grad: 0.4166
# Epoch: [1][300/1317]Data 0.000 (0.024)Elapsed 1m 35s (remain 5m 21s)Loss: 0.6825(1.3112)Grad: 0.3652
# Epoch: [1][320/1317]Data 0.000 (0.023)Elapsed 1m 42s (remain 5m 17s)Loss: 1.5686(1.3048)Grad: 0.4137
# Epoch: [1][340/1317]Data 0.000 (0.023)Elapsed 1m 48s (remain 5m 9s)Loss: 1.0944(1.2919)Grad: 0.3302
# Epoch: [1][360/1317]Data 0.000 (0.022)Elapsed 1m 54s (remain 5m 3s)Loss: 0.9140(1.2815)Grad: 0.3273
# Epoch: [1][380/1317]Data 0.046 (0.022)Elapsed 2m 0s (remain 4m 55s)Loss: 1.2002(1.2705)Grad: 0.2973
# Epoch: [1][400/1317]Data 0.009 (0.021)Elapsed 2m 6s (remain 4m 48s)Loss: 1.2639(1.2588)Grad: 0.3413
# Epoch: [1][420/1317]Data 0.168 (0.022)Elapsed 2m 13s (remain 4m 43s)Loss: 0.7902(1.2492)Grad: 0.3451
# Epoch: [1][440/1317]Data 0.000 (0.022)Elapsed 2m 19s (remain 4m 37s)Loss: 0.6617(1.2448)Grad: 0.3710
# Epoch: [1][460/1317]Data 0.043 (0.021)Elapsed 2m 25s (remain 4m 30s)Loss: 0.6863(1.2356)Grad: 0.3393
# Epoch: [1][480/1317]Data 0.145 (0.021)Elapsed 2m 31s (remain 4m 23s)Loss: 1.1054(1.2313)Grad: 0.4353
# Epoch: [1][500/1317]Data 0.108 (0.021)Elapsed 2m 37s (remain 4m 16s)Loss: 1.0280(1.2179)Grad: 0.4948
# Epoch: [1][520/1317]Data 0.046 (0.021)Elapsed 2m 44s (remain 4m 11s)Loss: 1.6327(1.2165)Grad: 0.4562
# Epoch: [1][540/1317]Data 0.088 (0.021)Elapsed 2m 50s (remain 4m 4s)Loss: 1.2154(1.2105)Grad: 0.3919
# Epoch: [1][560/1317]Data 0.145 (0.022)Elapsed 2m 56s (remain 3m 58s)Loss: 0.8565(1.2042)Grad: 0.3726
# Epoch: [1][580/1317]Data 0.000 (0.021)Elapsed 3m 3s (remain 3m 51s)Loss: 0.6602(1.1992)Grad: 0.4051
# Epoch: [1][600/1317]Data 0.000 (0.021)Elapsed 3m 9s (remain 3m 45s)Loss: 0.9278(1.1932)Grad: 0.4310
# Epoch: [1][620/1317]Data 0.001 (0.020)Elapsed 3m 15s (remain 3m 39s)Loss: 0.8742(1.1855)Grad: 0.3501
# Epoch: [1][640/1317]Data 0.068 (0.020)Elapsed 3m 21s (remain 3m 32s)Loss: 0.7239(1.1815)Grad: 0.3675
# Epoch: [1][660/1317]Data 0.003 (0.020)Elapsed 3m 27s (remain 3m 25s)Loss: 0.7612(1.1770)Grad: 0.3828
# Epoch: [1][680/1317]Data 0.108 (0.020)Elapsed 3m 33s (remain 3m 19s)Loss: 2.0223(1.1692)Grad: 0.5113
# Epoch: [1][700/1317]Data 0.005 (0.020)Elapsed 3m 39s (remain 3m 13s)Loss: 1.2253(1.1612)Grad: 0.3195
# Epoch: [1][720/1317]Data 0.003 (0.019)Elapsed 3m 47s (remain 3m 7s)Loss: 0.7248(1.1556)Grad: 0.3726
# Epoch: [1][740/1317]Data 0.003 (0.019)Elapsed 3m 53s (remain 3m 1s)Loss: 1.4499(1.1509)Grad: 0.4664
# Epoch: [1][760/1317]Data 0.207 (0.019)Elapsed 3m 59s (remain 2m 54s)Loss: 1.2475(1.1424)Grad: 0.4066
# Epoch: [1][780/1317]Data 0.000 (0.019)Elapsed 4m 5s (remain 2m 48s)Loss: 1.9239(1.1382)Grad: 0.4949
# Epoch: [1][800/1317]Data 0.000 (0.019)Elapsed 4m 10s (remain 2m 41s)Loss: 1.5860(1.1353)Grad: 0.4495
# Epoch: [1][820/1317]Data 0.000 (0.019)Elapsed 4m 17s (remain 2m 35s)Loss: 0.6081(1.1284)Grad: 0.3630
# Epoch: [1][840/1317]Data 0.002 (0.019)Elapsed 4m 23s (remain 2m 29s)Loss: 1.1834(1.1265)Grad: 0.4398
# Epoch: [1][860/1317]Data 0.000 (0.018)Elapsed 4m 30s (remain 2m 23s)Loss: 0.9996(1.1230)Grad: 0.4529
# Epoch: [1][880/1317]Data 0.000 (0.018)Elapsed 4m 36s (remain 2m 16s)Loss: 0.7793(1.1176)Grad: 0.4263
# Epoch: [1][900/1317]Data 0.001 (0.018)Elapsed 4m 42s (remain 2m 10s)Loss: 1.1411(1.1135)Grad: 0.4106
# Epoch: [1][920/1317]Data 0.000 (0.018)Elapsed 4m 48s (remain 2m 4s)Loss: 0.8313(1.1096)Grad: 0.3123
# Epoch: [1][940/1317]Data 0.000 (0.018)Elapsed 4m 55s (remain 1m 58s)Loss: 0.5458(1.1058)Grad: 0.3383
# Epoch: [1][960/1317]Data 0.006 (0.018)Elapsed 5m 1s (remain 1m 51s)Loss: 0.8873(1.1021)Grad: 0.3708
# Epoch: [1][980/1317]Data 0.089 (0.018)Elapsed 5m 7s (remain 1m 45s)Loss: 0.8177(1.0994)Grad: 0.4591
# Epoch: [1][1000/1317]Data 0.103 (0.019)Elapsed 5m 13s (remain 1m 39s)Loss: 0.7055(1.0974)Grad: 0.4012
# Epoch: [1][1020/1317]Data 0.001 (0.018)Elapsed 5m 19s (remain 1m 32s)Loss: 0.6364(1.0915)Grad: 0.3330
# Epoch: [1][1040/1317]Data 0.000 (0.018)Elapsed 5m 26s (remain 1m 26s)Loss: 0.5587(1.0878)Grad: 0.4540
# Epoch: [1][1060/1317]Data 0.000 (0.018)Elapsed 5m 32s (remain 1m 20s)Loss: 1.1824(1.0871)Grad: 0.3551
# Epoch: [1][1080/1317]Data 0.002 (0.018)Elapsed 5m 38s (remain 1m 13s)Loss: 1.1127(1.0860)Grad: 0.4131
# Epoch: [1][1100/1317]Data 0.000 (0.018)Elapsed 5m 44s (remain 1m 7s)Loss: 1.2806(1.0813)Grad: 0.4943
# Epoch: [1][1120/1317]Data 0.000 (0.018)Elapsed 5m 50s (remain 1m 1s)Loss: 0.7023(1.0791)Grad: 0.4520
# Epoch: [1][1140/1317]Data 0.000 (0.018)Elapsed 5m 57s (remain 0m 55s)Loss: 0.8256(1.0777)Grad: 0.4482
# Epoch: [1][1160/1317]Data 0.005 (0.018)Elapsed 6m 3s (remain 0m 48s)Loss: 1.6481(1.0729)Grad: 0.4525
# Epoch: [1][1180/1317]Data 0.000 (0.018)Elapsed 6m 9s (remain 0m 42s)Loss: 1.0448(1.0705)Grad: 0.4425
# Epoch: [1][1200/1317]Data 0.000 (0.018)Elapsed 6m 15s (remain 0m 36s)Loss: 0.6775(1.0672)Grad: 0.2866
# Epoch: [1][1220/1317]Data 0.001 (0.018)Elapsed 6m 21s (remain 0m 30s)Loss: 0.5780(1.0661)Grad: 0.3088
# Epoch: [1][1240/1317]Data 0.000 (0.018)Elapsed 6m 29s (remain 0m 23s)Loss: 0.5023(1.0636)Grad: 0.3082
# Epoch: [1][1260/1317]Data 0.000 (0.018)Elapsed 6m 34s (remain 0m 17s)Loss: 0.7854(1.0602)Grad: 0.3718
# Epoch: [1][1280/1317]Data 0.005 (0.018)Elapsed 6m 41s (remain 0m 11s)Loss: 0.7204(1.0590)Grad: 0.3043
# Epoch: [1][1300/1317]Data 0.002 (0.018)Elapsed 6m 47s (remain 0m 5s)Loss: 0.8095(1.0574)Grad: 0.2758
# Epoch: [1][1316/1317]Data 0.000 (0.018)Elapsed 6m 51s (remain 0m 0s)Loss: 1.5379(1.0561)Grad: 0.3892
# EVAL: [0/330] Data 0.950 (0.950) Elapsed 0m 1s (remain 5m 49s) Loss: 1.3970(1.3970)
# EVAL: [20/330] Data 0.340 (0.154) Elapsed 0m 5s (remain 1m 16s) Loss: 0.7160(0.7473)
# EVAL: [40/330] Data 0.319 (0.155) Elapsed 0m 10s (remain 1m 12s) Loss: 1.0091(0.8351)
# EVAL: [60/330] Data 0.421 (0.146) Elapsed 0m 14s (remain 1m 5s) Loss: 0.8440(0.8277)
# EVAL: [80/330] Data 0.507 (0.142) Elapsed 0m 19s (remain 0m 59s) Loss: 0.4007(0.8350)
# EVAL: [100/330] Data 0.485 (0.139) Elapsed 0m 23s (remain 0m 53s) Loss: 0.9204(0.8248)
# EVAL: [120/330] Data 0.274 (0.135) Elapsed 0m 27s (remain 0m 48s) Loss: 1.1163(0.8471)
# EVAL: [140/330] Data 0.443 (0.136) Elapsed 0m 32s (remain 0m 43s) Loss: 0.7017(0.8318)
# EVAL: [160/330] Data 0.324 (0.135) Elapsed 0m 37s (remain 0m 38s) Loss: 0.8663(0.8282)
# EVAL: [180/330] Data 0.373 (0.138) Elapsed 0m 42s (remain 0m 34s) Loss: 0.5676(0.8218)
# EVAL: [200/330] Data 0.345 (0.137) Elapsed 0m 46s (remain 0m 29s) Loss: 1.8468(0.8450)
# EVAL: [220/330] Data 0.208 (0.136) Elapsed 0m 50s (remain 0m 25s) Loss: 0.4724(0.8451)
# EVAL: [240/330] Data 0.241 (0.136) Elapsed 0m 55s (remain 0m 20s) Loss: 0.4381(0.8547)
# EVAL: [260/330] Data 0.098 (0.135) Elapsed 0m 59s (remain 0m 15s) Loss: 0.7827(0.8619)
# EVAL: [280/330] Data 0.247 (0.135) Elapsed 1m 4s (remain 0m 11s) Loss: 0.5588(0.8540)
# EVAL: [300/330] Data 0.403 (0.134) Elapsed 1m 8s (remain 0m 6s) Loss: 0.6983(0.8573)
# EVAL: [320/330] Data 0.301 (0.134) Elapsed 1m 13s (remain 0m 2s) Loss: 0.5398(0.8586)
# Epoch 1 - avg_train_loss: 1.0561 avg_val_loss: 0.8585 time: 486s
# Epoch 1 - Accuracy: 0.7201974183750949
# Epoch 1 - Save Best Score: 0.7202 Model
# EVAL: [329/330] Data 0.000 (0.132) Elapsed 1m 14s (remain 0m 0s) Loss: 0.4515(0.8585)
# requires_grad of all parameters are unlocked
# Epoch: [2][0/1317]Data 1.209 (1.209)Elapsed 0m 2s (remain 54m 37s)Loss: 1.0423(1.0423)Grad: 2.8351
# Epoch: [2][20/1317]Data 0.000 (0.058)Elapsed 0m 16s (remain 17m 21s)Loss: 1.6622(1.0624)Grad: 3.4300
# Epoch: [2][40/1317]Data 0.000 (0.030)Elapsed 0m 31s (remain 16m 16s)Loss: 1.3478(0.9950)Grad: 2.4754
# Epoch: [2][60/1317]Data 0.000 (0.020)Elapsed 0m 45s (remain 15m 43s)Loss: 0.6971(1.0044)Grad: 1.8901
# Epoch: [2][80/1317]Data 0.000 (0.015)Elapsed 1m 0s (remain 15m 22s)Loss: 0.3124(0.9682)Grad: 2.5805
# Epoch: [2][100/1317]Data 0.000 (0.012)Elapsed 1m 14s (remain 15m 0s)Loss: 0.6269(0.9181)Grad: 1.6354
# Epoch: [2][120/1317]Data 0.000 (0.010)Elapsed 1m 29s (remain 14m 41s)Loss: 0.5956(0.8888)Grad: 2.1576
# Epoch: [2][140/1317]Data 0.000 (0.009)Elapsed 1m 43s (remain 14m 24s)Loss: 1.3247(0.8682)Grad: 1.8946
# Epoch: [2][160/1317]Data 0.000 (0.008)Elapsed 1m 57s (remain 14m 7s)Loss: 0.4398(0.8433)Grad: 2.1300
# Epoch: [2][180/1317]Data 0.000 (0.007)Elapsed 2m 12s (remain 13m 52s)Loss: 0.8171(0.8598)Grad: 2.2282
# Epoch: [2][200/1317]Data 0.000 (0.006)Elapsed 2m 26s (remain 13m 35s)Loss: 0.5737(0.8480)Grad: 2.1602
# Epoch: [2][220/1317]Data 0.000 (0.006)Elapsed 2m 41s (remain 13m 20s)Loss: 1.4431(0.8631)Grad: 1.9787
# Epoch: [2][240/1317]Data 0.000 (0.005)Elapsed 2m 55s (remain 13m 5s)Loss: 0.3730(0.8498)Grad: 2.1743
# Epoch: [2][260/1317]Data 0.000 (0.005)Elapsed 3m 10s (remain 12m 50s)Loss: 0.4228(0.8486)Grad: 1.6598
# Epoch: [2][280/1317]Data 0.000 (0.004)Elapsed 3m 24s (remain 12m 34s)Loss: 0.5560(0.8416)Grad: 2.6084
# Epoch: [2][300/1317]Data 0.000 (0.004)Elapsed 3m 39s (remain 12m 19s)Loss: 1.5560(0.8267)Grad: 2.5114
# Epoch: [2][320/1317]Data 0.000 (0.004)Elapsed 3m 53s (remain 12m 5s)Loss: 0.5772(0.8174)Grad: 1.8294
# Epoch: [2][340/1317]Data 0.000 (0.004)Elapsed 4m 8s (remain 11m 50s)Loss: 0.2477(0.8149)Grad: 1.9098
# Epoch: [2][360/1317]Data 0.000 (0.004)Elapsed 4m 22s (remain 11m 36s)Loss: 1.2793(0.8155)Grad: 1.7416
# Epoch: [2][380/1317]Data 0.000 (0.003)Elapsed 4m 37s (remain 11m 21s)Loss: 0.7485(0.8060)Grad: 1.2524
# Epoch: [2][400/1317]Data 0.000 (0.003)Elapsed 4m 51s (remain 11m 6s)Loss: 0.4699(0.8066)Grad: 2.4657
# Epoch: [2][420/1317]Data 0.000 (0.003)Elapsed 5m 6s (remain 10m 51s)Loss: 0.4687(0.8062)Grad: 1.4775
# Epoch: [2][440/1317]Data 0.000 (0.003)Elapsed 5m 20s (remain 10m 37s)Loss: 0.2145(0.7975)Grad: 1.9037
# Epoch: [2][460/1317]Data 0.000 (0.003)Elapsed 5m 35s (remain 10m 22s)Loss: 0.7870(0.7932)Grad: 1.6614
# Epoch: [2][480/1317]Data 0.000 (0.003)Elapsed 5m 49s (remain 10m 7s)Loss: 0.8563(0.7889)Grad: 2.1493
# Epoch: [2][500/1317]Data 0.000 (0.003)Elapsed 6m 3s (remain 9m 52s)Loss: 0.6031(0.7796)Grad: 2.9310
# Epoch: [2][520/1317]Data 0.000 (0.002)Elapsed 6m 18s (remain 9m 37s)Loss: 0.8288(0.7776)Grad: 1.9356
# Epoch: [2][540/1317]Data 0.000 (0.002)Elapsed 6m 32s (remain 9m 23s)Loss: 1.7966(0.7824)Grad: 2.0736
# Epoch: [2][560/1317]Data 0.000 (0.002)Elapsed 6m 47s (remain 9m 8s)Loss: 0.2349(0.7738)Grad: 1.6175
# Epoch: [2][580/1317]Data 0.000 (0.002)Elapsed 7m 1s (remain 8m 54s)Loss: 0.4760(0.7710)Grad: 2.0817
# Epoch: [2][600/1317]Data 0.000 (0.002)Elapsed 7m 16s (remain 8m 39s)Loss: 0.4860(0.7636)Grad: 1.5357
# Epoch: [2][620/1317]Data 0.000 (0.002)Elapsed 7m 30s (remain 8m 24s)Loss: 0.2055(0.7589)Grad: 0.8487
# Epoch: [2][640/1317]Data 0.000 (0.002)Elapsed 7m 44s (remain 8m 10s)Loss: 0.6423(0.7572)Grad: 2.8980
# Epoch: [2][660/1317]Data 0.000 (0.002)Elapsed 7m 59s (remain 7m 55s)Loss: 0.3835(0.7546)Grad: 1.7142
# Epoch: [2][680/1317]Data 0.000 (0.002)Elapsed 8m 13s (remain 7m 40s)Loss: 0.8442(0.7519)Grad: 2.9325
# Epoch: [2][700/1317]Data 0.000 (0.002)Elapsed 8m 28s (remain 7m 26s)Loss: 0.2429(0.7488)Grad: 1.3776
# Epoch: [2][720/1317]Data 0.000 (0.002)Elapsed 8m 42s (remain 7m 11s)Loss: 0.8008(0.7458)Grad: 1.7140
# Epoch: [2][740/1317]Data 0.000 (0.002)Elapsed 8m 56s (remain 6m 57s)Loss: 0.5801(0.7383)Grad: 1.4662
# Epoch: [2][760/1317]Data 0.000 (0.002)Elapsed 9m 11s (remain 6m 42s)Loss: 0.5982(0.7326)Grad: 2.3048
# Epoch: [2][780/1317]Data 0.000 (0.002)Elapsed 9m 25s (remain 6m 28s)Loss: 0.4009(0.7262)Grad: 1.9273
# Epoch: [2][800/1317]Data 0.000 (0.002)Elapsed 9m 40s (remain 6m 13s)Loss: 0.8139(0.7240)Grad: 2.5421
# Epoch: [2][820/1317]Data 0.000 (0.002)Elapsed 9m 54s (remain 5m 59s)Loss: 0.3325(0.7197)Grad: 2.0951
# Epoch: [2][840/1317]Data 0.000 (0.002)Elapsed 10m 9s (remain 5m 44s)Loss: 1.1179(0.7203)Grad: 1.9942
# Epoch: [2][860/1317]Data 0.000 (0.002)Elapsed 10m 23s (remain 5m 30s)Loss: 3.1518(0.7224)Grad: 2.6682
# Epoch: [2][880/1317]Data 0.000 (0.002)Elapsed 10m 37s (remain 5m 15s)Loss: 0.6745(0.7249)Grad: 1.3041
# Epoch: [2][900/1317]Data 0.000 (0.002)Elapsed 10m 52s (remain 5m 1s)Loss: 0.5046(0.7206)Grad: 2.1534
# Epoch: [2][920/1317]Data 0.000 (0.001)Elapsed 11m 6s (remain 4m 46s)Loss: 0.8738(0.7153)Grad: 2.4582
# Epoch: [2][940/1317]Data 0.000 (0.001)Elapsed 11m 21s (remain 4m 32s)Loss: 1.1332(0.7143)Grad: 2.1535
# Epoch: [2][960/1317]Data 0.000 (0.001)Elapsed 11m 35s (remain 4m 17s)Loss: 0.4085(0.7174)Grad: 1.4586
# Epoch: [2][980/1317]Data 0.000 (0.001)Elapsed 11m 50s (remain 4m 3s)Loss: 1.2097(0.7136)Grad: 2.3357
# Epoch: [2][1000/1317]Data 0.000 (0.001)Elapsed 12m 4s (remain 3m 48s)Loss: 1.5848(0.7119)Grad: 2.1889
# Epoch: [2][1020/1317]Data 0.000 (0.001)Elapsed 12m 19s (remain 3m 34s)Loss: 0.5433(0.7103)Grad: 2.3441
# Epoch: [2][1040/1317]Data 0.000 (0.001)Elapsed 12m 33s (remain 3m 19s)Loss: 0.8104(0.7098)Grad: 1.1105
# Epoch: [2][1060/1317]Data 0.000 (0.001)Elapsed 12m 47s (remain 3m 5s)Loss: 0.3876(0.7069)Grad: 2.1383
# Epoch: [2][1080/1317]Data 0.000 (0.001)Elapsed 13m 2s (remain 2m 50s)Loss: 0.1394(0.7076)Grad: 1.6109
# Epoch: [2][1100/1317]Data 0.000 (0.001)Elapsed 13m 16s (remain 2m 36s)Loss: 0.4751(0.7029)Grad: 1.6812
# Epoch: [2][1120/1317]Data 0.000 (0.001)Elapsed 13m 31s (remain 2m 21s)Loss: 0.3522(0.7045)Grad: 2.0306
# Epoch: [2][1140/1317]Data 0.000 (0.001)Elapsed 13m 45s (remain 2m 7s)Loss: 1.1626(0.7053)Grad: 2.4815
# Epoch: [2][1160/1317]Data 0.000 (0.001)Elapsed 14m 0s (remain 1m 52s)Loss: 1.5351(0.7045)Grad: 2.5091
# Epoch: [2][1180/1317]Data 0.000 (0.001)Elapsed 14m 14s (remain 1m 38s)Loss: 0.2010(0.7017)Grad: 0.9159
# Epoch: [2][1200/1317]Data 0.000 (0.001)Elapsed 14m 29s (remain 1m 23s)Loss: 0.6647(0.7013)Grad: 1.6879
# Epoch: [2][1220/1317]Data 0.000 (0.001)Elapsed 14m 43s (remain 1m 9s)Loss: 0.4101(0.6983)Grad: 1.7231
# Epoch: [2][1240/1317]Data 0.000 (0.001)Elapsed 14m 57s (remain 0m 54s)Loss: 1.2824(0.6992)Grad: 1.5409
# Epoch: [2][1260/1317]Data 0.000 (0.001)Elapsed 15m 12s (remain 0m 40s)Loss: 0.6135(0.6962)Grad: 1.5477
# Epoch: [2][1280/1317]Data 0.000 (0.001)Elapsed 15m 26s (remain 0m 26s)Loss: 1.2976(0.6966)Grad: 2.4658
# Epoch: [2][1300/1317]Data 0.000 (0.001)Elapsed 15m 41s (remain 0m 11s)Loss: 0.1464(0.6945)Grad: 0.7127
# Epoch: [2][1316/1317]Data 0.000 (0.001)Elapsed 15m 52s (remain 0m 0s)Loss: 0.0771(0.6941)Grad: 1.0633
# EVAL: [0/330] Data 0.787 (0.787) Elapsed 0m 0s (remain 5m 5s) Loss: 0.4777(0.4777)
# EVAL: [20/330] Data 0.484 (0.160) Elapsed 0m 5s (remain 1m 18s) Loss: 0.1568(0.4737)
# EVAL: [40/330] Data 0.300 (0.130) Elapsed 0m 9s (remain 1m 5s) Loss: 0.9426(0.5266)
# EVAL: [60/330] Data 0.218 (0.128) Elapsed 0m 13s (remain 1m 0s) Loss: 0.3642(0.5110)
# EVAL: [80/330] Data 0.478 (0.132) Elapsed 0m 18s (remain 0m 57s) Loss: 0.3732(0.5655)
# EVAL: [100/330] Data 0.232 (0.127) Elapsed 0m 22s (remain 0m 51s) Loss: 0.3361(0.5610)
# EVAL: [120/330] Data 0.011 (0.127) Elapsed 0m 26s (remain 0m 46s) Loss: 0.2697(0.5635)
# EVAL: [140/330] Data 0.317 (0.126) Elapsed 0m 31s (remain 0m 41s) Loss: 0.1614(0.5348)
# EVAL: [160/330] Data 0.496 (0.125) Elapsed 0m 35s (remain 0m 37s) Loss: 0.7762(0.5378)
# EVAL: [180/330] Data 0.392 (0.124) Elapsed 0m 39s (remain 0m 32s) Loss: 0.6369(0.5342)
# EVAL: [200/330] Data 0.425 (0.123) Elapsed 0m 43s (remain 0m 28s) Loss: 0.4347(0.5456)
# EVAL: [220/330] Data 0.656 (0.125) Elapsed 0m 48s (remain 0m 24s) Loss: 0.2251(0.5379)
# EVAL: [240/330] Data 0.467 (0.125) Elapsed 0m 53s (remain 0m 19s) Loss: 0.0161(0.5440)
# EVAL: [260/330] Data 0.298 (0.123) Elapsed 0m 56s (remain 0m 15s) Loss: 1.0133(0.5506)
# EVAL: [280/330] Data 0.182 (0.122) Elapsed 1m 1s (remain 0m 10s) Loss: 0.2638(0.5458)
# EVAL: [300/330] Data 0.000 (0.121) Elapsed 1m 5s (remain 0m 6s) Loss: 0.1864(0.5434)
# EVAL: [320/330] Data 0.000 (0.119) Elapsed 1m 8s (remain 0m 1s) Loss: 0.4038(0.5461)
# Epoch 2 - avg_train_loss: 0.6941 avg_val_loss: 0.5476 time: 1023s
# Epoch 2 - Accuracy: 0.8559225512528473
# Epoch 2 - Save Best Score: 0.8559 Model
# EVAL: [329/330] Data 0.000 (0.117) Elapsed 1m 10s (remain 0m 0s) Loss: 0.0192(0.5476)
# Epoch: [3][0/1317]Data 1.219 (1.219)Elapsed 0m 2s (remain 50m 43s)Loss: 0.5405(0.5405)Grad: 2.0238
# Epoch: [3][20/1317]Data 0.000 (0.058)Elapsed 0m 16s (remain 17m 15s)Loss: 1.0601(0.6228)Grad: 1.7210
# Epoch: [3][40/1317]Data 0.000 (0.030)Elapsed 0m 31s (remain 16m 8s)Loss: 1.4291(0.5643)Grad: 2.1532
# Epoch: [3][60/1317]Data 0.000 (0.020)Elapsed 0m 45s (remain 15m 40s)Loss: 0.1261(0.6548)Grad: 0.9231
# Epoch: [3][80/1317]Data 0.000 (0.015)Elapsed 0m 59s (remain 15m 15s)Loss: 1.0948(0.6432)Grad: 1.6315
# Epoch: [3][100/1317]Data 0.000 (0.012)Elapsed 1m 14s (remain 14m 54s)Loss: 0.1590(0.6531)Grad: 1.7971
# Epoch: [3][120/1317]Data 0.000 (0.010)Elapsed 1m 28s (remain 14m 38s)Loss: 0.0731(0.6359)Grad: 1.2223
# Epoch: [3][140/1317]Data 0.000 (0.009)Elapsed 1m 43s (remain 14m 21s)Loss: 0.5502(0.6384)Grad: 1.7403
# Epoch: [3][160/1317]Data 0.000 (0.008)Elapsed 1m 57s (remain 14m 4s)Loss: 0.3792(0.6135)Grad: 1.4378
# Epoch: [3][180/1317]Data 0.000 (0.007)Elapsed 2m 12s (remain 13m 48s)Loss: 1.0948(0.5986)Grad: 1.4363
# Epoch: [3][200/1317]Data 0.000 (0.006)Elapsed 2m 26s (remain 13m 33s)Loss: 1.7427(0.5977)Grad: 1.6396
# Epoch: [3][220/1317]Data 0.000 (0.006)Elapsed 2m 40s (remain 13m 17s)Loss: 0.3964(0.5900)Grad: 0.6164
# Epoch: [3][240/1317]Data 0.000 (0.005)Elapsed 2m 55s (remain 13m 3s)Loss: 0.1973(0.5993)Grad: 2.2964
# Epoch: [3][260/1317]Data 0.000 (0.005)Elapsed 3m 9s (remain 12m 47s)Loss: 0.6505(0.6148)Grad: 1.6190
# Epoch: [3][280/1317]Data 0.000 (0.005)Elapsed 3m 24s (remain 12m 32s)Loss: 0.0577(0.6137)Grad: 1.1644
# Epoch: [3][300/1317]Data 0.000 (0.004)Elapsed 3m 38s (remain 12m 17s)Loss: 0.5894(0.6047)Grad: 2.1786
# Epoch: [3][320/1317]Data 0.000 (0.004)Elapsed 3m 52s (remain 12m 2s)Loss: 0.3236(0.6040)Grad: 1.9460
# Epoch: [3][340/1317]Data 0.000 (0.004)Elapsed 4m 7s (remain 11m 48s)Loss: 0.0481(0.6060)Grad: 0.6969
# Epoch: [3][360/1317]Data 0.000 (0.004)Elapsed 4m 21s (remain 11m 33s)Loss: 0.1574(0.6026)Grad: 1.2806
# Epoch: [3][380/1317]Data 0.000 (0.003)Elapsed 4m 36s (remain 11m 18s)Loss: 0.9866(0.6058)Grad: 0.9737
# Epoch: [3][400/1317]Data 0.000 (0.003)Elapsed 4m 50s (remain 11m 4s)Loss: 1.1158(0.6126)Grad: 2.3920
# Epoch: [3][420/1317]Data 0.000 (0.003)Elapsed 5m 5s (remain 10m 49s)Loss: 0.4739(0.6128)Grad: 1.7583
# Epoch: [3][440/1317]Data 0.000 (0.003)Elapsed 5m 19s (remain 10m 34s)Loss: 0.1511(0.6094)Grad: 0.9148
# Epoch: [3][460/1317]Data 0.000 (0.003)Elapsed 5m 33s (remain 10m 19s)Loss: 0.0760(0.6092)Grad: 0.6891
# Epoch: [3][480/1317]Data 0.000 (0.003)Elapsed 5m 48s (remain 10m 5s)Loss: 0.9853(0.6146)Grad: 1.5853
# Epoch: [3][500/1317]Data 0.000 (0.003)Elapsed 6m 2s (remain 9m 51s)Loss: 0.5396(0.6120)Grad: 2.0533
# Epoch: [3][520/1317]Data 0.000 (0.002)Elapsed 6m 17s (remain 9m 36s)Loss: 0.3351(0.6101)Grad: 1.8860
# Epoch: [3][540/1317]Data 0.000 (0.002)Elapsed 6m 31s (remain 9m 21s)Loss: 0.8285(0.6122)Grad: 1.4163
# Epoch: [3][560/1317]Data 0.000 (0.002)Elapsed 6m 46s (remain 9m 7s)Loss: 0.2350(0.6071)Grad: 1.4861
# Epoch: [3][580/1317]Data 0.000 (0.002)Elapsed 7m 0s (remain 8m 52s)Loss: 0.8774(0.6072)Grad: 1.0080
# Epoch: [3][600/1317]Data 0.000 (0.002)Elapsed 7m 14s (remain 8m 38s)Loss: 1.8243(0.6093)Grad: 1.2690
# Epoch: [3][620/1317]Data 0.000 (0.002)Elapsed 7m 29s (remain 8m 23s)Loss: 0.3930(0.6137)Grad: 1.0778
# Epoch: [3][640/1317]Data 0.000 (0.002)Elapsed 7m 43s (remain 8m 9s)Loss: 0.6110(0.6126)Grad: 0.9689
# Epoch: [3][660/1317]Data 0.000 (0.002)Elapsed 7m 58s (remain 7m 54s)Loss: 1.0277(0.6112)Grad: 1.6775
# Epoch: [3][680/1317]Data 0.000 (0.002)Elapsed 8m 12s (remain 7m 40s)Loss: 0.3994(0.6105)Grad: 1.4222
# Epoch: [3][700/1317]Data 0.000 (0.002)Elapsed 8m 27s (remain 7m 25s)Loss: 0.5475(0.6051)Grad: 1.4701
# Epoch: [3][720/1317]Data 0.000 (0.002)Elapsed 8m 41s (remain 7m 11s)Loss: 1.2998(0.6034)Grad: 1.9750
# Epoch: [3][740/1317]Data 0.000 (0.002)Elapsed 8m 56s (remain 6m 56s)Loss: 0.4060(0.6058)Grad: 1.4614
# Epoch: [3][760/1317]Data 0.000 (0.002)Elapsed 9m 10s (remain 6m 42s)Loss: 1.0713(0.6073)Grad: 1.8263
# Epoch: [3][780/1317]Data 0.000 (0.002)Elapsed 9m 24s (remain 6m 27s)Loss: 0.5533(0.6077)Grad: 1.7295
# Epoch: [3][800/1317]Data 0.000 (0.002)Elapsed 9m 39s (remain 6m 13s)Loss: 0.6042(0.6057)Grad: 1.1639
# Epoch: [3][820/1317]Data 0.000 (0.002)Elapsed 9m 53s (remain 5m 58s)Loss: 0.2970(0.6060)Grad: 1.2014
# Epoch: [3][840/1317]Data 0.000 (0.002)Elapsed 10m 8s (remain 5m 44s)Loss: 0.2083(0.6053)Grad: 0.8319
# Epoch: [3][860/1317]Data 0.000 (0.002)Elapsed 10m 22s (remain 5m 29s)Loss: 0.5547(0.6025)Grad: 2.3554
# Epoch: [3][880/1317]Data 0.000 (0.002)Elapsed 10m 37s (remain 5m 15s)Loss: 0.5108(0.6018)Grad: 1.3595
# Epoch: [3][900/1317]Data 0.000 (0.002)Elapsed 10m 51s (remain 5m 0s)Loss: 0.0932(0.5986)Grad: 1.0721
# Epoch: [3][920/1317]Data 0.000 (0.001)Elapsed 11m 6s (remain 4m 46s)Loss: 0.4168(0.6010)Grad: 1.7594
# Epoch: [3][940/1317]Data 0.000 (0.001)Elapsed 11m 20s (remain 4m 31s)Loss: 0.1522(0.5988)Grad: 0.7036
# Epoch: [3][960/1317]Data 0.000 (0.001)Elapsed 11m 34s (remain 4m 17s)Loss: 1.8303(0.6019)Grad: 2.2867
# Epoch: [3][980/1317]Data 0.000 (0.001)Elapsed 11m 49s (remain 4m 2s)Loss: 1.4725(0.5986)Grad: 1.4981
# Epoch: [3][1000/1317]Data 0.000 (0.001)Elapsed 12m 3s (remain 3m 48s)Loss: 0.2279(0.6013)Grad: 1.2120
# Epoch: [3][1020/1317]Data 0.000 (0.001)Elapsed 12m 18s (remain 3m 34s)Loss: 0.1219(0.5999)Grad: 1.2210
# Epoch: [3][1040/1317]Data 0.000 (0.001)Elapsed 12m 32s (remain 3m 19s)Loss: 0.6097(0.6022)Grad: 1.4501
# Epoch: [3][1060/1317]Data 0.000 (0.001)Elapsed 12m 46s (remain 3m 5s)Loss: 0.0501(0.6038)Grad: 0.7755
# Epoch: [3][1080/1317]Data 0.000 (0.001)Elapsed 13m 1s (remain 2m 50s)Loss: 0.3592(0.6040)Grad: 1.4435
# Epoch: [3][1100/1317]Data 0.000 (0.001)Elapsed 13m 15s (remain 2m 36s)Loss: 0.3398(0.6024)Grad: 1.4566
# Epoch: [3][1120/1317]Data 0.000 (0.001)Elapsed 13m 30s (remain 2m 21s)Loss: 0.2183(0.6005)Grad: 1.7394
# Epoch: [3][1140/1317]Data 0.000 (0.001)Elapsed 13m 44s (remain 2m 7s)Loss: 0.4737(0.6003)Grad: 1.5074
# Epoch: [3][1160/1317]Data 0.000 (0.001)Elapsed 13m 58s (remain 1m 52s)Loss: 2.2014(0.6042)Grad: 1.3163
# Epoch: [3][1180/1317]Data 0.000 (0.001)Elapsed 14m 13s (remain 1m 38s)Loss: 2.3086(0.6080)Grad: 2.3116
# Epoch: [3][1200/1317]Data 0.000 (0.001)Elapsed 14m 27s (remain 1m 23s)Loss: 0.1851(0.6086)Grad: 1.0611
# Epoch: [3][1220/1317]Data 0.000 (0.001)Elapsed 14m 42s (remain 1m 9s)Loss: 1.4462(0.6070)Grad: 2.3232
# Epoch: [3][1240/1317]Data 0.000 (0.001)Elapsed 14m 56s (remain 0m 54s)Loss: 0.3924(0.6060)Grad: 0.9743
# Epoch: [3][1260/1317]Data 0.000 (0.001)Elapsed 15m 11s (remain 0m 40s)Loss: 0.3247(0.6079)Grad: 0.9226
# Epoch: [3][1280/1317]Data 0.000 (0.001)Elapsed 15m 25s (remain 0m 26s)Loss: 0.4158(0.6058)Grad: 1.9424
# Epoch: [3][1300/1317]Data 0.000 (0.001)Elapsed 15m 39s (remain 0m 11s)Loss: 0.5497(0.6051)Grad: 1.1950
# Epoch: [3][1316/1317]Data 0.000 (0.001)Elapsed 15m 51s (remain 0m 0s)Loss: 0.2224(0.6065)Grad: 1.1430
# EVAL: [0/330] Data 0.910 (0.910) Elapsed 0m 1s (remain 5m 45s) Loss: 0.7185(0.7185)
# EVAL: [20/330] Data 0.438 (0.153) Elapsed 0m 5s (remain 1m 19s) Loss: 0.0666(0.5197)
# EVAL: [40/330] Data 0.583 (0.141) Elapsed 0m 9s (remain 1m 9s) Loss: 0.8470(0.5559)
# EVAL: [60/330] Data 0.384 (0.130) Elapsed 0m 13s (remain 1m 1s) Loss: 0.3403(0.5183)
# EVAL: [80/330] Data 0.402 (0.126) Elapsed 0m 18s (remain 0m 55s) Loss: 0.3371(0.5587)
# EVAL: [100/330] Data 0.049 (0.120) Elapsed 0m 21s (remain 0m 49s) Loss: 0.2793(0.5595)
# EVAL: [120/330] Data 0.264 (0.120) Elapsed 0m 26s (remain 0m 45s) Loss: 0.1917(0.5686)
# EVAL: [140/330] Data 0.736 (0.125) Elapsed 0m 31s (remain 0m 42s) Loss: 0.1298(0.5360)
# EVAL: [160/330] Data 0.341 (0.122) Elapsed 0m 35s (remain 0m 37s) Loss: 0.8915(0.5351)
# EVAL: [180/330] Data 0.290 (0.122) Elapsed 0m 39s (remain 0m 32s) Loss: 0.5617(0.5270)
# EVAL: [200/330] Data 0.000 (0.121) Elapsed 0m 43s (remain 0m 28s) Loss: 0.4028(0.5425)
# EVAL: [220/330] Data 0.000 (0.120) Elapsed 0m 47s (remain 0m 23s) Loss: 0.0958(0.5320)
# EVAL: [240/330] Data 0.000 (0.121) Elapsed 0m 52s (remain 0m 19s) Loss: 0.0073(0.5357)
# EVAL: [260/330] Data 0.065 (0.119) Elapsed 0m 56s (remain 0m 14s) Loss: 1.2040(0.5421)
# EVAL: [280/330] Data 0.000 (0.119) Elapsed 1m 0s (remain 0m 10s) Loss: 0.1886(0.5379)
# EVAL: [300/330] Data 0.206 (0.118) Elapsed 1m 4s (remain 0m 6s) Loss: 0.2879(0.5364)
# EVAL: [320/330] Data 0.059 (0.117) Elapsed 1m 8s (remain 0m 1s) Loss: 0.2983(0.5375)
# Epoch 3 - avg_train_loss: 0.6065 avg_val_loss: 0.5380 time: 1021s
# Epoch 3 - Accuracy: 0.8722475322703113
# Epoch 3 - Save Best Score: 0.8722 Model
# EVAL: [329/330] Data 0.000 (0.115) Elapsed 1m 9s (remain 0m 0s) Loss: 0.0075(0.5380)
# Epoch: [4][0/1317]Data 1.468 (1.468)Elapsed 0m 2s (remain 65m 43s)Loss: 0.1839(0.1839)Grad: 1.1179
# Epoch: [4][20/1317]Data 0.000 (0.070)Elapsed 0m 17s (remain 18m 3s)Loss: 0.8936(0.5109)Grad: 1.6150
# Epoch: [4][40/1317]Data 0.000 (0.036)Elapsed 0m 31s (remain 16m 33s)Loss: 0.3296(0.5536)Grad: 2.0263
# Epoch: [4][60/1317]Data 0.000 (0.024)Elapsed 0m 46s (remain 15m 56s)Loss: 0.2212(0.5561)Grad: 1.2609
# Epoch: [4][80/1317]Data 0.000 (0.018)Elapsed 1m 0s (remain 15m 27s)Loss: 0.1875(0.5419)Grad: 1.7527
# Epoch: [4][100/1317]Data 0.000 (0.015)Elapsed 1m 15s (remain 15m 6s)Loss: 0.4302(0.5201)Grad: 1.3373
# Epoch: [4][120/1317]Data 0.000 (0.012)Elapsed 1m 29s (remain 14m 46s)Loss: 0.3563(0.5412)Grad: 0.6299
# Epoch: [4][140/1317]Data 0.000 (0.011)Elapsed 1m 44s (remain 14m 28s)Loss: 0.5577(0.5489)Grad: 1.3837
# Epoch: [4][160/1317]Data 0.000 (0.009)Elapsed 1m 58s (remain 14m 11s)Loss: 0.2650(0.5751)Grad: 1.0934
# Epoch: [4][180/1317]Data 0.000 (0.008)Elapsed 2m 13s (remain 13m 54s)Loss: 0.7156(0.5706)Grad: 1.8950
# Epoch: [4][200/1317]Data 0.000 (0.007)Elapsed 2m 27s (remain 13m 39s)Loss: 1.8005(0.5755)Grad: 1.5013
# Epoch: [4][220/1317]Data 0.000 (0.007)Elapsed 2m 41s (remain 13m 23s)Loss: 0.1853(0.5735)Grad: 1.4793
# Epoch: [4][240/1317]Data 0.000 (0.006)Elapsed 2m 56s (remain 13m 7s)Loss: 0.5995(0.5727)Grad: 1.8154
# Epoch: [4][260/1317]Data 0.000 (0.006)Elapsed 3m 11s (remain 12m 52s)Loss: 0.1892(0.5741)Grad: 1.0312
# Epoch: [4][280/1317]Data 0.000 (0.005)Elapsed 3m 25s (remain 12m 37s)Loss: 0.8148(0.5772)Grad: 1.3431
# Epoch: [4][300/1317]Data 0.000 (0.005)Elapsed 3m 40s (remain 12m 22s)Loss: 0.0117(0.5705)Grad: 0.3563
# Epoch: [4][320/1317]Data 0.000 (0.005)Elapsed 3m 54s (remain 12m 7s)Loss: 0.5898(0.5832)Grad: 1.0617
# Epoch: [4][340/1317]Data 0.000 (0.004)Elapsed 4m 9s (remain 11m 52s)Loss: 0.2376(0.5749)Grad: 0.8553
# Epoch: [4][360/1317]Data 0.000 (0.004)Elapsed 4m 23s (remain 11m 37s)Loss: 0.2237(0.5718)Grad: 0.7989
# Epoch: [4][380/1317]Data 0.000 (0.004)Elapsed 4m 37s (remain 11m 22s)Loss: 0.4165(0.5704)Grad: 1.3912
# Epoch: [4][400/1317]Data 0.000 (0.004)Elapsed 4m 52s (remain 11m 7s)Loss: 2.8460(0.5813)Grad: 1.5422
# Epoch: [4][420/1317]Data 0.000 (0.004)Elapsed 5m 6s (remain 10m 52s)Loss: 0.3374(0.5825)Grad: 0.8938
# Epoch: [4][440/1317]Data 0.000 (0.003)Elapsed 5m 21s (remain 10m 37s)Loss: 1.1249(0.5865)Grad: 1.9647
# Epoch: [4][460/1317]Data 0.000 (0.003)Elapsed 5m 35s (remain 10m 23s)Loss: 0.9600(0.5997)Grad: 1.3656
# Epoch: [4][480/1317]Data 0.000 (0.003)Elapsed 5m 50s (remain 10m 8s)Loss: 0.4237(0.5989)Grad: 1.5067
# Epoch: [4][500/1317]Data 0.000 (0.003)Elapsed 6m 4s (remain 9m 53s)Loss: 0.0944(0.6059)Grad: 1.3649
# Epoch: [4][520/1317]Data 0.000 (0.003)Elapsed 6m 18s (remain 9m 39s)Loss: 0.3632(0.6016)Grad: 1.1420
# Epoch: [4][540/1317]Data 0.000 (0.003)Elapsed 6m 33s (remain 9m 24s)Loss: 0.8073(0.5962)Grad: 2.2366
# Epoch: [4][560/1317]Data 0.000 (0.003)Elapsed 6m 47s (remain 9m 9s)Loss: 0.1802(0.5973)Grad: 2.0426
# Epoch: [4][580/1317]Data 0.000 (0.003)Elapsed 7m 2s (remain 8m 54s)Loss: 0.2965(0.5967)Grad: 1.6725
# Epoch: [4][600/1317]Data 0.000 (0.003)Elapsed 7m 16s (remain 8m 40s)Loss: 0.6149(0.5942)Grad: 1.2585
# Epoch: [4][620/1317]Data 0.000 (0.003)Elapsed 7m 31s (remain 8m 25s)Loss: 0.3761(0.5922)Grad: 1.4894
# Epoch: [4][640/1317]Data 0.000 (0.002)Elapsed 7m 45s (remain 8m 11s)Loss: 0.7905(0.5895)Grad: 1.0926
# Epoch: [4][660/1317]Data 0.000 (0.002)Elapsed 8m 0s (remain 7m 56s)Loss: 0.0256(0.5888)Grad: 0.4178
# Epoch: [4][680/1317]Data 0.000 (0.002)Elapsed 8m 14s (remain 7m 41s)Loss: 0.2396(0.5847)Grad: 1.9184
# Epoch: [4][700/1317]Data 0.000 (0.002)Elapsed 8m 29s (remain 7m 27s)Loss: 0.4372(0.5830)Grad: 0.9831
# Epoch: [4][720/1317]Data 0.000 (0.002)Elapsed 8m 43s (remain 7m 12s)Loss: 1.1287(0.5800)Grad: 1.6955
# Epoch: [4][740/1317]Data 0.000 (0.002)Elapsed 8m 57s (remain 6m 58s)Loss: 0.1235(0.5826)Grad: 1.1199
# Epoch: [4][760/1317]Data 0.000 (0.002)Elapsed 9m 12s (remain 6m 43s)Loss: 1.2692(0.5881)Grad: 2.0134
# Epoch: [4][780/1317]Data 0.000 (0.002)Elapsed 9m 26s (remain 6m 28s)Loss: 0.3150(0.5850)Grad: 1.1213
# Epoch: [4][800/1317]Data 0.000 (0.002)Elapsed 9m 41s (remain 6m 14s)Loss: 0.9344(0.5859)Grad: 1.0460
# Epoch: [4][820/1317]Data 0.000 (0.002)Elapsed 9m 55s (remain 5m 59s)Loss: 0.3015(0.5840)Grad: 1.9277
# Epoch: [4][840/1317]Data 0.000 (0.002)Elapsed 10m 9s (remain 5m 45s)Loss: 1.9809(0.5869)Grad: 1.0987
# Epoch: [4][860/1317]Data 0.000 (0.002)Elapsed 10m 24s (remain 5m 30s)Loss: 1.7037(0.5858)Grad: 1.3152
# Epoch: [4][880/1317]Data 0.000 (0.002)Elapsed 10m 38s (remain 5m 16s)Loss: 0.3708(0.5900)Grad: 1.4834
# Epoch: [4][900/1317]Data 0.000 (0.002)Elapsed 10m 53s (remain 5m 1s)Loss: 0.9950(0.5882)Grad: 1.6660
# Epoch: [4][920/1317]Data 0.000 (0.002)Elapsed 11m 7s (remain 4m 47s)Loss: 0.0162(0.5884)Grad: 0.5584
# Epoch: [4][940/1317]Data 0.000 (0.002)Elapsed 11m 22s (remain 4m 32s)Loss: 0.9753(0.5891)Grad: 1.6340
# Epoch: [4][960/1317]Data 0.000 (0.002)Elapsed 11m 36s (remain 4m 18s)Loss: 1.0206(0.5885)Grad: 1.4731
# Epoch: [4][980/1317]Data 0.000 (0.002)Elapsed 11m 50s (remain 4m 3s)Loss: 3.2581(0.5890)Grad: 3.3981
# Epoch: [4][1000/1317]Data 0.000 (0.002)Elapsed 12m 5s (remain 3m 49s)Loss: 1.6233(0.5912)Grad: 1.3577
# Epoch: [4][1020/1317]Data 0.000 (0.002)Elapsed 12m 20s (remain 3m 34s)Loss: 0.5719(0.5900)Grad: 1.1581
# Epoch: [4][1040/1317]Data 0.000 (0.002)Elapsed 12m 34s (remain 3m 20s)Loss: 1.2526(0.5914)Grad: 1.7231
# Epoch: [4][1060/1317]Data 0.000 (0.002)Elapsed 12m 48s (remain 3m 5s)Loss: 0.3607(0.5977)Grad: 1.6548
# Epoch: [4][1080/1317]Data 0.000 (0.002)Elapsed 13m 3s (remain 2m 51s)Loss: 0.3617(0.5961)Grad: 0.7203
# Epoch: [4][1100/1317]Data 0.000 (0.001)Elapsed 13m 17s (remain 2m 36s)Loss: 0.3657(0.5948)Grad: 1.3153
# Epoch: [4][1120/1317]Data 0.000 (0.001)Elapsed 13m 32s (remain 2m 22s)Loss: 0.2207(0.5913)Grad: 1.2232
# Epoch: [4][1140/1317]Data 0.000 (0.001)Elapsed 13m 46s (remain 2m 7s)Loss: 0.2870(0.5865)Grad: 1.1443
# Epoch: [4][1160/1317]Data 0.000 (0.001)Elapsed 14m 1s (remain 1m 53s)Loss: 0.9995(0.5880)Grad: 1.9819
# Epoch: [4][1180/1317]Data 0.000 (0.001)Elapsed 14m 15s (remain 1m 38s)Loss: 0.0900(0.5871)Grad: 0.9777
# Epoch: [4][1200/1317]Data 0.000 (0.001)Elapsed 14m 30s (remain 1m 24s)Loss: 0.5247(0.5895)Grad: 1.5639
# Epoch: [4][1220/1317]Data 0.000 (0.001)Elapsed 14m 44s (remain 1m 9s)Loss: 1.1053(0.5866)Grad: 0.8042
# Epoch: [4][1240/1317]Data 0.000 (0.001)Elapsed 14m 58s (remain 0m 55s)Loss: 1.2992(0.5839)Grad: 2.0023
# Epoch: [4][1260/1317]Data 0.000 (0.001)Elapsed 15m 13s (remain 0m 40s)Loss: 0.0271(0.5797)Grad: 0.3743
# Epoch: [4][1280/1317]Data 0.000 (0.001)Elapsed 15m 27s (remain 0m 26s)Loss: 0.0897(0.5801)Grad: 0.6799
# Epoch: [4][1300/1317]Data 0.000 (0.001)Elapsed 15m 42s (remain 0m 11s)Loss: 0.4744(0.5774)Grad: 1.4916
# Epoch: [4][1316/1317]Data 0.000 (0.001)Elapsed 15m 53s (remain 0m 0s)Loss: 1.5717(0.5803)Grad: 1.5503
# EVAL: [0/330] Data 1.032 (1.032) Elapsed 0m 1s (remain 6m 6s) Loss: 0.6485(0.6485)
# EVAL: [20/330] Data 0.690 (0.167) Elapsed 0m 5s (remain 1m 21s) Loss: 0.0626(0.5599)
# EVAL: [40/330] Data 0.322 (0.139) Elapsed 0m 9s (remain 1m 7s) Loss: 1.0302(0.5994)
# EVAL: [60/330] Data 0.442 (0.132) Elapsed 0m 13s (remain 1m 0s) Loss: 0.2429(0.5527)
# EVAL: [80/330] Data 0.462 (0.132) Elapsed 0m 18s (remain 0m 56s) Loss: 0.3237(0.5648)
# EVAL: [100/330] Data 0.330 (0.126) Elapsed 0m 22s (remain 0m 50s) Loss: 0.2435(0.5692)
# EVAL: [120/330] Data 0.549 (0.125) Elapsed 0m 26s (remain 0m 45s) Loss: 0.2252(0.5861)
# EVAL: [140/330] Data 0.252 (0.127) Elapsed 0m 31s (remain 0m 41s) Loss: 0.2881(0.5531)
# EVAL: [160/330] Data 0.403 (0.127) Elapsed 0m 35s (remain 0m 37s) Loss: 0.9259(0.5483)
# EVAL: [180/330] Data 0.335 (0.126) Elapsed 0m 39s (remain 0m 32s) Loss: 0.5837(0.5404)
# EVAL: [200/330] Data 0.360 (0.126) Elapsed 0m 44s (remain 0m 28s) Loss: 0.4697(0.5583)
# EVAL: [220/330] Data 0.373 (0.125) Elapsed 0m 48s (remain 0m 23s) Loss: 0.0263(0.5472)
# EVAL: [240/330] Data 0.417 (0.125) Elapsed 0m 52s (remain 0m 19s) Loss: 0.0057(0.5490)
# EVAL: [260/330] Data 0.172 (0.123) Elapsed 0m 56s (remain 0m 14s) Loss: 1.6797(0.5540)
# EVAL: [280/330] Data 0.326 (0.122) Elapsed 1m 0s (remain 0m 10s) Loss: 0.2412(0.5492)
# EVAL: [300/330] Data 0.106 (0.121) Elapsed 1m 5s (remain 0m 6s) Loss: 0.4313(0.5477)
# EVAL: [320/330] Data 0.001 (0.120) Elapsed 1m 8s (remain 0m 1s) Loss: 0.2024(0.5521)
# Epoch 4 - avg_train_loss: 0.5803 avg_val_loss: 0.5541 time: 1024s
# Epoch 4 - Accuracy: 0.873006833712984
# Epoch 4 - Save Best Score: 0.8730 Model
# EVAL: [329/330] Data 0.000 (0.118) Elapsed 1m 10s (remain 0m 0s) Loss: 0.0051(0.5541)
# Epoch: [5][0/1317]Data 1.323 (1.323)Elapsed 0m 2s (remain 51m 35s)Loss: 0.0157(0.0157)Grad: 0.5198
# Epoch: [5][20/1317]Data 0.000 (0.063)Elapsed 0m 16s (remain 17m 19s)Loss: 0.2814(0.6444)Grad: 1.1891
# Epoch: [5][40/1317]Data 0.000 (0.032)Elapsed 0m 31s (remain 16m 15s)Loss: 0.2902(0.5806)Grad: 1.5265
# Epoch: [5][60/1317]Data 0.000 (0.022)Elapsed 0m 45s (remain 15m 43s)Loss: 0.1772(0.5097)Grad: 0.9567
# Epoch: [5][80/1317]Data 0.000 (0.016)Elapsed 1m 0s (remain 15m 20s)Loss: 0.0487(0.5360)Grad: 1.0419
# Epoch: [5][100/1317]Data 0.000 (0.013)Elapsed 1m 14s (remain 14m 59s)Loss: 0.6039(0.5987)Grad: 1.4003
# Epoch: [5][120/1317]Data 0.000 (0.011)Elapsed 1m 29s (remain 14m 41s)Loss: 0.6566(0.5801)Grad: 1.6765
# Epoch: [5][140/1317]Data 0.000 (0.010)Elapsed 1m 43s (remain 14m 23s)Loss: 0.8976(0.6035)Grad: 0.8069
# Epoch: [5][160/1317]Data 0.000 (0.008)Elapsed 1m 57s (remain 14m 7s)Loss: 1.3745(0.5984)Grad: 1.6674
# Epoch: [5][180/1317]Data 0.000 (0.007)Elapsed 2m 12s (remain 13m 51s)Loss: 0.2069(0.6198)Grad: 1.2571
# Epoch: [5][200/1317]Data 0.000 (0.007)Elapsed 2m 26s (remain 13m 35s)Loss: 0.0920(0.6084)Grad: 0.8959
# Epoch: [5][220/1317]Data 0.000 (0.006)Elapsed 2m 41s (remain 13m 20s)Loss: 0.1634(0.6206)Grad: 1.3919
# Epoch: [5][240/1317]Data 0.000 (0.006)Elapsed 2m 55s (remain 13m 4s)Loss: 0.6062(0.6268)Grad: 0.6554
# Epoch: [5][260/1317]Data 0.000 (0.005)Elapsed 3m 10s (remain 12m 50s)Loss: 0.7939(0.6144)Grad: 1.4396
# Epoch: [5][280/1317]Data 0.000 (0.005)Elapsed 3m 24s (remain 12m 34s)Loss: 1.3123(0.6104)Grad: 1.9056
# Epoch: [5][300/1317]Data 0.000 (0.005)Elapsed 3m 39s (remain 12m 19s)Loss: 0.7016(0.6106)Grad: 1.1436
# Epoch: [5][320/1317]Data 0.000 (0.004)Elapsed 3m 53s (remain 12m 4s)Loss: 0.4559(0.5990)Grad: 1.0621
# Epoch: [5][340/1317]Data 0.000 (0.004)Elapsed 4m 8s (remain 11m 49s)Loss: 0.4508(0.5961)Grad: 0.7885
# Epoch: [5][360/1317]Data 0.000 (0.004)Elapsed 4m 22s (remain 11m 34s)Loss: 0.1030(0.5939)Grad: 1.3164
# Epoch: [5][380/1317]Data 0.000 (0.004)Elapsed 4m 36s (remain 11m 20s)Loss: 0.0156(0.5857)Grad: 0.5148
# Epoch: [5][400/1317]Data 0.000 (0.003)Elapsed 4m 51s (remain 11m 5s)Loss: 0.4046(0.5891)Grad: 1.2533
# Epoch: [5][420/1317]Data 0.000 (0.003)Elapsed 5m 5s (remain 10m 50s)Loss: 0.0876(0.5853)Grad: 0.6013
# Epoch: [5][440/1317]Data 0.000 (0.003)Elapsed 5m 20s (remain 10m 35s)Loss: 0.7097(0.5833)Grad: 1.0223
# Epoch: [5][460/1317]Data 0.000 (0.003)Elapsed 5m 34s (remain 10m 21s)Loss: 0.1700(0.5734)Grad: 1.1779
# Epoch: [5][480/1317]Data 0.000 (0.003)Elapsed 5m 48s (remain 10m 6s)Loss: 0.3336(0.5652)Grad: 1.2919
# Epoch: [5][500/1317]Data 0.000 (0.003)Elapsed 6m 3s (remain 9m 51s)Loss: 0.6021(0.5617)Grad: 1.1712
# Epoch: [5][520/1317]Data 0.000 (0.003)Elapsed 6m 17s (remain 9m 37s)Loss: 0.2641(0.5660)Grad: 1.2769
# Epoch: [5][540/1317]Data 0.000 (0.003)Elapsed 6m 32s (remain 9m 22s)Loss: 0.5317(0.5673)Grad: 1.0753
# Epoch: [5][560/1317]Data 0.000 (0.003)Elapsed 6m 46s (remain 9m 8s)Loss: 0.7473(0.5652)Grad: 0.5085
# Epoch: [5][580/1317]Data 0.000 (0.002)Elapsed 7m 1s (remain 8m 53s)Loss: 0.7252(0.5701)Grad: 1.7395
# Epoch: [5][600/1317]Data 0.000 (0.002)Elapsed 7m 15s (remain 8m 38s)Loss: 0.3899(0.5676)Grad: 0.6664
# Epoch: [5][620/1317]Data 0.000 (0.002)Elapsed 7m 30s (remain 8m 24s)Loss: 0.1774(0.5648)Grad: 1.1323
# Epoch: [5][640/1317]Data 0.000 (0.002)Elapsed 7m 44s (remain 8m 9s)Loss: 0.0947(0.5637)Grad: 0.8741
# Epoch: [5][660/1317]Data 0.000 (0.002)Elapsed 7m 58s (remain 7m 55s)Loss: 0.1569(0.5615)Grad: 0.9628
# Epoch: [5][680/1317]Data 0.000 (0.002)Elapsed 8m 13s (remain 7m 40s)Loss: 0.3599(0.5571)Grad: 1.0723
# Epoch: [5][700/1317]Data 0.000 (0.002)Elapsed 8m 27s (remain 7m 26s)Loss: 0.0886(0.5573)Grad: 1.0643
# Epoch: [5][720/1317]Data 0.000 (0.002)Elapsed 8m 42s (remain 7m 11s)Loss: 1.2317(0.5604)Grad: 1.6962
# Epoch: [5][740/1317]Data 0.000 (0.002)Elapsed 8m 56s (remain 6m 57s)Loss: 0.6661(0.5607)Grad: 1.2034
# Epoch: [5][760/1317]Data 0.000 (0.002)Elapsed 9m 11s (remain 6m 42s)Loss: 0.3307(0.5589)Grad: 0.5930
# Epoch: [5][780/1317]Data 0.000 (0.002)Elapsed 9m 25s (remain 6m 28s)Loss: 0.1560(0.5585)Grad: 1.4297
# Epoch: [5][800/1317]Data 0.000 (0.002)Elapsed 9m 40s (remain 6m 13s)Loss: 0.8750(0.5568)Grad: 1.0130
# Epoch: [5][820/1317]Data 0.000 (0.002)Elapsed 9m 54s (remain 5m 59s)Loss: 0.5182(0.5548)Grad: 1.6461
# Epoch: [5][840/1317]Data 0.000 (0.002)Elapsed 10m 9s (remain 5m 44s)Loss: 0.9480(0.5549)Grad: 1.5530
# Epoch: [5][860/1317]Data 0.000 (0.002)Elapsed 10m 23s (remain 5m 30s)Loss: 0.7154(0.5568)Grad: 1.1253
# Epoch: [5][880/1317]Data 0.000 (0.002)Elapsed 10m 38s (remain 5m 15s)Loss: 0.5590(0.5536)Grad: 0.6604
# Epoch: [5][900/1317]Data 0.000 (0.002)Elapsed 10m 52s (remain 5m 1s)Loss: 0.0886(0.5566)Grad: 0.7399
# Epoch: [5][920/1317]Data 0.000 (0.002)Elapsed 11m 6s (remain 4m 46s)Loss: 0.7227(0.5564)Grad: 1.1668
# Epoch: [5][940/1317]Data 0.000 (0.002)Elapsed 11m 21s (remain 4m 32s)Loss: 0.4632(0.5579)Grad: 0.7242
# Epoch: [5][960/1317]Data 0.000 (0.002)Elapsed 11m 35s (remain 4m 17s)Loss: 0.1201(0.5570)Grad: 1.3866
# Epoch: [5][980/1317]Data 0.000 (0.002)Elapsed 11m 50s (remain 4m 3s)Loss: 0.1746(0.5602)Grad: 0.9309
# Epoch: [5][1000/1317]Data 0.000 (0.001)Elapsed 12m 4s (remain 3m 48s)Loss: 0.7707(0.5617)Grad: 1.8669
# Epoch: [5][1020/1317]Data 0.000 (0.001)Elapsed 12m 19s (remain 3m 34s)Loss: 0.0350(0.5585)Grad: 0.6062
# Epoch: [5][1040/1317]Data 0.000 (0.001)Elapsed 12m 33s (remain 3m 19s)Loss: 0.8608(0.5574)Grad: 1.7976
# Epoch: [5][1060/1317]Data 0.000 (0.001)Elapsed 12m 48s (remain 3m 5s)Loss: 1.6446(0.5608)Grad: 1.0437
# Epoch: [5][1080/1317]Data 0.000 (0.001)Elapsed 13m 2s (remain 2m 50s)Loss: 0.3381(0.5605)Grad: 1.7880
# Epoch: [5][1100/1317]Data 0.000 (0.001)Elapsed 13m 16s (remain 2m 36s)Loss: 0.1008(0.5610)Grad: 0.8738
# Epoch: [5][1120/1317]Data 0.000 (0.001)Elapsed 13m 31s (remain 2m 21s)Loss: 0.5198(0.5606)Grad: 1.5639
# Epoch: [5][1140/1317]Data 0.000 (0.001)Elapsed 13m 45s (remain 2m 7s)Loss: 0.7540(0.5636)Grad: 1.4631
# Epoch: [5][1160/1317]Data 0.000 (0.001)Elapsed 14m 0s (remain 1m 52s)Loss: 0.3944(0.5652)Grad: 1.2408
# Epoch: [5][1180/1317]Data 0.000 (0.001)Elapsed 14m 14s (remain 1m 38s)Loss: 0.8448(0.5649)Grad: 1.8310
# Epoch: [5][1200/1317]Data 0.000 (0.001)Elapsed 14m 29s (remain 1m 23s)Loss: 1.1633(0.5662)Grad: 1.2130
# Epoch: [5][1220/1317]Data 0.000 (0.001)Elapsed 14m 43s (remain 1m 9s)Loss: 0.2681(0.5652)Grad: 1.5953
# Epoch: [5][1240/1317]Data 0.000 (0.001)Elapsed 14m 58s (remain 0m 54s)Loss: 0.6925(0.5646)Grad: 1.0577
# Epoch: [5][1260/1317]Data 0.000 (0.001)Elapsed 15m 12s (remain 0m 40s)Loss: 0.1322(0.5629)Grad: 1.2349
# Epoch: [5][1280/1317]Data 0.000 (0.001)Elapsed 15m 27s (remain 0m 26s)Loss: 1.6401(0.5644)Grad: 2.0244
# Epoch: [5][1300/1317]Data 0.000 (0.001)Elapsed 15m 41s (remain 0m 11s)Loss: 0.3403(0.5631)Grad: 1.3112
# Epoch: [5][1316/1317]Data 0.000 (0.001)Elapsed 15m 52s (remain 0m 0s)Loss: 0.5254(0.5610)Grad: 1.5465
# EVAL: [0/330] Data 1.076 (1.076) Elapsed 0m 1s (remain 6m 41s) Loss: 0.7508(0.7508)
# EVAL: [20/330] Data 0.656 (0.193) Elapsed 0m 6s (remain 1m 31s) Loss: 0.0597(0.5521)
# EVAL: [40/330] Data 0.336 (0.149) Elapsed 0m 10s (remain 1m 11s) Loss: 0.9010(0.5873)
# EVAL: [60/330] Data 0.250 (0.140) Elapsed 0m 14s (remain 1m 2s) Loss: 0.4912(0.5335)
# EVAL: [80/330] Data 0.369 (0.136) Elapsed 0m 18s (remain 0m 57s) Loss: 0.3396(0.5533)
# EVAL: [100/330] Data 0.249 (0.131) Elapsed 0m 22s (remain 0m 51s) Loss: 0.3384(0.5562)
# EVAL: [120/330] Data 0.206 (0.128) Elapsed 0m 26s (remain 0m 46s) Loss: 0.0987(0.5694)
# EVAL: [140/330] Data 0.000 (0.126) Elapsed 0m 31s (remain 0m 41s) Loss: 0.1947(0.5346)
# EVAL: [160/330] Data 0.000 (0.126) Elapsed 0m 35s (remain 0m 37s) Loss: 0.6578(0.5299)
# EVAL: [180/330] Data 0.000 (0.127) Elapsed 0m 40s (remain 0m 33s) Loss: 0.4557(0.5228)
# EVAL: [200/330] Data 0.085 (0.126) Elapsed 0m 44s (remain 0m 28s) Loss: 0.4219(0.5389)
# EVAL: [220/330] Data 0.245 (0.125) Elapsed 0m 49s (remain 0m 24s) Loss: 0.0348(0.5284)
# EVAL: [240/330] Data 0.484 (0.125) Elapsed 0m 53s (remain 0m 19s) Loss: 0.0077(0.5277)
# EVAL: [260/330] Data 0.452 (0.123) Elapsed 0m 57s (remain 0m 15s) Loss: 1.8066(0.5366)
# EVAL: [280/330] Data 0.427 (0.124) Elapsed 1m 2s (remain 0m 10s) Loss: 0.1242(0.5284)
# EVAL: [300/330] Data 0.270 (0.122) Elapsed 1m 5s (remain 0m 6s) Loss: 0.4460(0.5238)
# EVAL: [320/330] Data 0.511 (0.121) Elapsed 1m 10s (remain 0m 1s) Loss: 0.2882(0.5306)
# Epoch 5 - avg_train_loss: 0.5610 avg_val_loss: 0.5303 time: 1024s
# Epoch 5 - Accuracy: 0.8777524677296887
# Epoch 5 - Save Best Score: 0.8778 Model
# EVAL: [329/330] Data 0.000 (0.119) Elapsed 1m 11s (remain 0m 0s) Loss: 0.0018(0.5303)
# Epoch: [6][0/1317]Data 1.278 (1.278)Elapsed 0m 2s (remain 49m 56s)Loss: 0.0707(0.0707)Grad: 0.9670
# Epoch: [6][20/1317]Data 0.000 (0.061)Elapsed 0m 16s (remain 17m 8s)Loss: 0.3713(0.3996)Grad: 0.7168
# Epoch: [6][40/1317]Data 0.000 (0.031)Elapsed 0m 31s (remain 16m 10s)Loss: 0.8530(0.4976)Grad: 1.9020
# Epoch: [6][60/1317]Data 0.000 (0.021)Elapsed 0m 45s (remain 15m 39s)Loss: 0.2841(0.5179)Grad: 1.8207
# Epoch: [6][80/1317]Data 0.000 (0.016)Elapsed 1m 0s (remain 15m 16s)Loss: 0.1294(0.5252)Grad: 1.4789
# Epoch: [6][100/1317]Data 0.000 (0.013)Elapsed 1m 14s (remain 14m 57s)Loss: 0.6526(0.5430)Grad: 2.1945
# Epoch: [6][120/1317]Data 0.000 (0.011)Elapsed 1m 28s (remain 14m 39s)Loss: 0.0379(0.5271)Grad: 1.1804
# Epoch: [6][140/1317]Data 0.000 (0.009)Elapsed 1m 43s (remain 14m 22s)Loss: 0.1524(0.5578)Grad: 1.0707
# Epoch: [6][160/1317]Data 0.000 (0.008)Elapsed 1m 57s (remain 14m 5s)Loss: 0.8865(0.5494)Grad: 0.9513
# Epoch: [6][180/1317]Data 0.000 (0.007)Elapsed 2m 12s (remain 13m 50s)Loss: 0.2107(0.5443)Grad: 1.3521
# Epoch: [6][200/1317]Data 0.000 (0.007)Elapsed 2m 26s (remain 13m 34s)Loss: 0.1790(0.5266)Grad: 0.9484
# Epoch: [6][220/1317]Data 0.000 (0.006)Elapsed 2m 41s (remain 13m 18s)Loss: 0.3851(0.5255)Grad: 1.9549
# Epoch: [6][240/1317]Data 0.000 (0.005)Elapsed 2m 55s (remain 13m 3s)Loss: 0.1313(0.5223)Grad: 1.2975
# Epoch: [6][260/1317]Data 0.000 (0.005)Elapsed 3m 9s (remain 12m 48s)Loss: 0.3053(0.5187)Grad: 1.5214
# Epoch: [6][280/1317]Data 0.000 (0.005)Elapsed 3m 24s (remain 12m 33s)Loss: 0.2879(0.5191)Grad: 1.3595
# Epoch: [6][300/1317]Data 0.000 (0.004)Elapsed 3m 38s (remain 12m 18s)Loss: 0.6147(0.5247)Grad: 1.5955
# Epoch: [6][320/1317]Data 0.000 (0.004)Elapsed 3m 53s (remain 12m 3s)Loss: 0.3489(0.5249)Grad: 1.7962
# Epoch: [6][340/1317]Data 0.000 (0.004)Elapsed 4m 7s (remain 11m 48s)Loss: 0.3053(0.5262)Grad: 0.9344
# Epoch: [6][360/1317]Data 0.000 (0.004)Elapsed 4m 21s (remain 11m 33s)Loss: 0.1414(0.5220)Grad: 1.2413
# Epoch: [6][380/1317]Data 0.000 (0.004)Elapsed 4m 36s (remain 11m 18s)Loss: 0.6369(0.5283)Grad: 2.0226
# Epoch: [6][400/1317]Data 0.000 (0.003)Elapsed 4m 50s (remain 11m 4s)Loss: 1.2781(0.5381)Grad: 1.8662
# Epoch: [6][420/1317]Data 0.000 (0.003)Elapsed 5m 5s (remain 10m 49s)Loss: 0.5580(0.5389)Grad: 1.0317
# Epoch: [6][440/1317]Data 0.000 (0.003)Elapsed 5m 19s (remain 10m 34s)Loss: 0.1277(0.5454)Grad: 1.1718
# Epoch: [6][460/1317]Data 0.000 (0.003)Elapsed 5m 33s (remain 10m 20s)Loss: 1.7395(0.5417)Grad: 1.1916
# Epoch: [6][480/1317]Data 0.000 (0.003)Elapsed 5m 48s (remain 10m 5s)Loss: 0.3870(0.5427)Grad: 1.7385
# Epoch: [6][500/1317]Data 0.000 (0.003)Elapsed 6m 2s (remain 9m 50s)Loss: 1.1023(0.5389)Grad: 0.7599
# Epoch: [6][520/1317]Data 0.000 (0.003)Elapsed 6m 17s (remain 9m 36s)Loss: 0.1691(0.5339)Grad: 1.6507
# Epoch: [6][540/1317]Data 0.000 (0.003)Elapsed 6m 31s (remain 9m 22s)Loss: 0.1564(0.5349)Grad: 1.5576
# Epoch: [6][560/1317]Data 0.000 (0.002)Elapsed 6m 46s (remain 9m 7s)Loss: 0.1977(0.5315)Grad: 0.8645
# Epoch: [6][580/1317]Data 0.000 (0.002)Elapsed 7m 0s (remain 8m 52s)Loss: 6.6632(0.5378)Grad: 2.1017
# Epoch: [6][600/1317]Data 0.000 (0.002)Elapsed 7m 15s (remain 8m 38s)Loss: 0.3205(0.5358)Grad: 1.3863
# Epoch: [6][620/1317]Data 0.000 (0.002)Elapsed 7m 29s (remain 8m 23s)Loss: 1.6478(0.5358)Grad: 0.5507
# Epoch: [6][640/1317]Data 0.000 (0.002)Elapsed 7m 43s (remain 8m 9s)Loss: 0.8345(0.5367)Grad: 1.6863
# Epoch: [6][660/1317]Data 0.000 (0.002)Elapsed 7m 58s (remain 7m 54s)Loss: 0.2818(0.5356)Grad: 1.7281
# Epoch: [6][680/1317]Data 0.000 (0.002)Elapsed 8m 12s (remain 7m 40s)Loss: 0.6447(0.5369)Grad: 0.9431
# Epoch: [6][700/1317]Data 0.000 (0.002)Elapsed 8m 27s (remain 7m 25s)Loss: 0.7585(0.5344)Grad: 1.0726
# Epoch: [6][720/1317]Data 0.000 (0.002)Elapsed 8m 41s (remain 7m 11s)Loss: 0.6259(0.5347)Grad: 1.9386
# Epoch: [6][740/1317]Data 0.000 (0.002)Elapsed 8m 56s (remain 6m 56s)Loss: 1.7230(0.5405)Grad: 0.8572
# Epoch: [6][760/1317]Data 0.000 (0.002)Elapsed 9m 10s (remain 6m 42s)Loss: 2.8331(0.5416)Grad: 1.4847
# Epoch: [6][780/1317]Data 0.000 (0.002)Elapsed 9m 25s (remain 6m 27s)Loss: 0.1776(0.5430)Grad: 0.7636
# Epoch: [6][800/1317]Data 0.000 (0.002)Elapsed 9m 39s (remain 6m 13s)Loss: 0.4243(0.5434)Grad: 0.6511
# Epoch: [6][820/1317]Data 0.000 (0.002)Elapsed 9m 54s (remain 5m 58s)Loss: 0.1090(0.5448)Grad: 0.7174
# Epoch: [6][840/1317]Data 0.000 (0.002)Elapsed 10m 8s (remain 5m 44s)Loss: 0.6804(0.5433)Grad: 1.2257
# ...
# Epoch: [9][280/1317]Data 0.000 (0.004)Elapsed 3m 24s (remain 12m 32s)Loss: 0.3652(0.5252)Grad: 1.0209
# Epoch: [9][300/1317]Data 0.000 (0.003)Elapsed 3m 38s (remain 12m 18s)Loss: 0.0417(0.5198)Grad: 0.8559
# Epoch: [9][320/1317]Data 0.000 (0.003)Elapsed 3m 53s (remain 12m 3s)Loss: 0.4650(0.5104)Grad: 1.6888
# Epoch: [9][340/1317]Data 0.000 (0.003)Elapsed 4m 7s (remain 11m 49s)Loss: 0.0388(0.5030)Grad: 0.6574
# Epoch: [9][360/1317]Data 0.000 (0.003)Elapsed 4m 22s (remain 11m 34s)Loss: 0.0257(0.4939)Grad: 0.6792
# Epoch: [9][380/1317]Data 0.000 (0.003)Elapsed 4m 36s (remain 11m 20s)Loss: 0.0505(0.4992)Grad: 0.7868
# Epoch: [9][400/1317]Data 0.000 (0.003)Elapsed 4m 51s (remain 11m 5s)Loss: 0.1596(0.4956)Grad: 0.8577
# Epoch: [9][420/1317]Data 0.000 (0.002)Elapsed 5m 5s (remain 10m 50s)Loss: 0.2942(0.5118)Grad: 1.0607
# Epoch: [9][440/1317]Data 0.000 (0.002)Elapsed 5m 20s (remain 10m 36s)Loss: 0.0425(0.5156)Grad: 0.6118
# Epoch: [9][460/1317]Data 0.000 (0.002)Elapsed 5m 34s (remain 10m 21s)Loss: 0.0545(0.5140)Grad: 0.5454
# Epoch: [9][480/1317]Data 0.000 (0.002)Elapsed 5m 49s (remain 10m 7s)Loss: 0.0490(0.5080)Grad: 0.7195
# Epoch: [9][500/1317]Data 0.000 (0.002)Elapsed 6m 3s (remain 9m 52s)Loss: 0.7689(0.5090)Grad: 1.9398
# Epoch: [9][520/1317]Data 0.000 (0.002)Elapsed 6m 18s (remain 9m 38s)Loss: 0.0777(0.5181)Grad: 0.8701
# Epoch: [9][540/1317]Data 0.000 (0.002)Elapsed 6m 32s (remain 9m 23s)Loss: 1.0502(0.5198)Grad: 1.5511
# Epoch: [9][560/1317]Data 0.000 (0.002)Elapsed 6m 47s (remain 9m 8s)Loss: 0.2505(0.5205)Grad: 1.6196
# Epoch: [9][580/1317]Data 0.000 (0.002)Elapsed 7m 1s (remain 8m 54s)Loss: 0.2575(0.5147)Grad: 1.4846
# Epoch: [9][600/1317]Data 0.000 (0.002)Elapsed 7m 16s (remain 8m 39s)Loss: 0.2308(0.5126)Grad: 1.4300
# Epoch: [9][620/1317]Data 0.000 (0.002)Elapsed 7m 30s (remain 8m 25s)Loss: 0.9088(0.5088)Grad: 1.2543
# Epoch: [9][640/1317]Data 0.000 (0.002)Elapsed 7m 45s (remain 8m 10s)Loss: 0.5545(0.5129)Grad: 0.6465
# Epoch: [9][660/1317]Data 0.000 (0.002)Elapsed 7m 59s (remain 7m 56s)Loss: 0.2285(0.5131)Grad: 1.5787
# Epoch: [9][680/1317]Data 0.000 (0.002)Elapsed 8m 14s (remain 7m 41s)Loss: 0.0486(0.5092)Grad: 1.1393
# Epoch: [9][700/1317]Data 0.000 (0.002)Elapsed 8m 28s (remain 7m 26s)Loss: 0.0380(0.5114)Grad: 0.5380
# Epoch: [9][720/1317]Data 0.000 (0.001)Elapsed 8m 43s (remain 7m 12s)Loss: 0.4218(0.5122)Grad: 1.1062
# Epoch: [9][740/1317]Data 0.000 (0.001)Elapsed 8m 57s (remain 6m 57s)Loss: 0.1351(0.5133)Grad: 1.1443
# Epoch: [9][760/1317]Data 0.000 (0.001)Elapsed 9m 12s (remain 6m 43s)Loss: 0.0246(0.5105)Grad: 0.6187
# Epoch: [9][780/1317]Data 0.000 (0.001)Elapsed 9m 26s (remain 6m 28s)Loss: 0.2941(0.5105)Grad: 0.7879
# Epoch: [9][800/1317]Data 0.000 (0.001)Elapsed 9m 41s (remain 6m 14s)Loss: 0.1348(0.5077)Grad: 1.1944
# Epoch: [9][820/1317]Data 0.000 (0.001)Elapsed 9m 55s (remain 5m 59s)Loss: 0.7445(0.5052)Grad: 1.1616
# Epoch: [9][840/1317]Data 0.000 (0.001)Elapsed 10m 9s (remain 5m 45s)Loss: 0.0923(0.5052)Grad: 0.8733
# Epoch: [9][860/1317]Data 0.000 (0.001)Elapsed 10m 24s (remain 5m 30s)Loss: 0.4925(0.5018)Grad: 1.1355
# Epoch: [9][880/1317]Data 0.000 (0.001)Elapsed 10m 38s (remain 5m 16s)Loss: 1.0673(0.5001)Grad: 1.5411
# Epoch: [9][900/1317]Data 0.000 (0.001)Elapsed 10m 53s (remain 5m 1s)Loss: 0.6008(0.5010)Grad: 1.5378
# Epoch: [9][920/1317]Data 0.000 (0.001)Elapsed 11m 7s (remain 4m 47s)Loss: 0.5061(0.5000)Grad: 0.8768
# Epoch: [9][940/1317]Data 0.000 (0.001)Elapsed 11m 22s (remain 4m 32s)Loss: 2.1461(0.5025)Grad: 1.4709
# Epoch: [9][960/1317]Data 0.000 (0.001)Elapsed 11m 36s (remain 4m 18s)Loss: 0.0462(0.4991)Grad: 1.0208
# Epoch: [9][980/1317]Data 0.000 (0.001)Elapsed 11m 50s (remain 4m 3s)Loss: 1.3250(0.5012)Grad: 1.4447
# Epoch: [9][1000/1317]Data 0.000 (0.001)Elapsed 12m 5s (remain 3m 48s)Loss: 0.2973(0.5004)Grad: 1.0561
# Epoch: [9][1020/1317]Data 0.000 (0.001)Elapsed 12m 19s (remain 3m 34s)Loss: 0.1371(0.5063)Grad: 1.4739
# Epoch: [9][1040/1317]Data 0.000 (0.001)Elapsed 12m 34s (remain 3m 19s)Loss: 0.2456(0.5021)Grad: 0.8779
# Epoch: [9][1060/1317]Data 0.000 (0.001)Elapsed 12m 48s (remain 3m 5s)Loss: 0.2379(0.4994)Grad: 1.7192
# Epoch: [9][1080/1317]Data 0.000 (0.001)Elapsed 13m 3s (remain 2m 50s)Loss: 0.3487(0.5032)Grad: 1.0043
# Epoch: [9][1100/1317]Data 0.000 (0.001)Elapsed 13m 17s (remain 2m 36s)Loss: 0.6262(0.4995)Grad: 1.5852
# Epoch: [9][1120/1317]Data 0.000 (0.001)Elapsed 13m 31s (remain 2m 21s)Loss: 2.9966(0.5031)Grad: 1.1873
# Epoch: [9][1140/1317]Data 0.000 (0.001)Elapsed 13m 46s (remain 2m 7s)Loss: 0.4521(0.5045)Grad: 0.5322
# Epoch: [9][1160/1317]Data 0.000 (0.001)Elapsed 14m 0s (remain 1m 52s)Loss: 0.3194(0.5008)Grad: 1.5437
# Epoch: [9][1180/1317]Data 0.000 (0.001)Elapsed 14m 15s (remain 1m 38s)Loss: 0.5141(0.4998)Grad: 1.2326
# Epoch: [9][1200/1317]Data 0.000 (0.001)Elapsed 14m 29s (remain 1m 24s)Loss: 0.3607(0.5005)Grad: 1.5474
# Epoch: [9][1220/1317]Data 0.000 (0.001)Elapsed 14m 44s (remain 1m 9s)Loss: 0.4823(0.5013)Grad: 1.5061
# Epoch: [9][1240/1317]Data 0.000 (0.001)Elapsed 14m 58s (remain 0m 55s)Loss: 0.1134(0.5004)Grad: 0.8900
# Epoch: [9][1260/1317]Data 0.000 (0.001)Elapsed 15m 13s (remain 0m 40s)Loss: 0.5545(0.4980)Grad: 1.4075
# Epoch: [9][1280/1317]Data 0.000 (0.001)Elapsed 15m 27s (remain 0m 26s)Loss: 1.7708(0.4976)Grad: 1.3048
# Epoch: [9][1300/1317]Data 0.000 (0.001)Elapsed 15m 42s (remain 0m 11s)Loss: 0.1714(0.5000)Grad: 1.8862
# Epoch: [9][1316/1317]Data 0.000 (0.001)Elapsed 15m 53s (remain 0m 0s)Loss: 0.4284(0.5029)Grad: 1.1726
# EVAL: [0/330] Data 1.095 (1.095) Elapsed 0m 1s (remain 6m 30s) Loss: 0.4168(0.4168)
# EVAL: [20/330] Data 0.270 (0.147) Elapsed 0m 5s (remain 1m 13s) Loss: 0.4083(0.5208)
# EVAL: [40/330] Data 0.577 (0.131) Elapsed 0m 9s (remain 1m 4s) Loss: 0.3665(0.5692)
# EVAL: [60/330] Data 0.397 (0.125) Elapsed 0m 13s (remain 0m 58s) Loss: 0.3192(0.5564)
# EVAL: [80/330] Data 0.458 (0.119) Elapsed 0m 17s (remain 0m 52s) Loss: 2.0277(0.6396)
# EVAL: [100/330] Data 0.289 (0.112) Elapsed 0m 20s (remain 0m 47s) Loss: 0.7232(0.6058)
# EVAL: [120/330] Data 0.346 (0.115) Elapsed 0m 25s (remain 0m 43s) Loss: 0.5611(0.5802)
# EVAL: [140/330] Data 0.515 (0.113) Elapsed 0m 29s (remain 0m 39s) Loss: 0.3983(0.5647)
# EVAL: [160/330] Data 0.312 (0.114) Elapsed 0m 33s (remain 0m 35s) Loss: 0.1616(0.5558)
# EVAL: [180/330] Data 0.187 (0.113) Elapsed 0m 37s (remain 0m 31s) Loss: 0.2374(0.5436)
# EVAL: [200/330] Data 0.147 (0.113) Elapsed 0m 41s (remain 0m 26s) Loss: 0.0004(0.5350)
# EVAL: [220/330] Data 0.131 (0.113) Elapsed 0m 46s (remain 0m 22s) Loss: 1.0730(0.5333)
# EVAL: [240/330] Data 0.435 (0.112) Elapsed 0m 50s (remain 0m 18s) Loss: 0.4577(0.5171)
# EVAL: [260/330] Data 0.000 (0.111) Elapsed 0m 53s (remain 0m 14s) Loss: 0.8191(0.5089)
# EVAL: [280/330] Data 0.000 (0.111) Elapsed 0m 57s (remain 0m 10s) Loss: 0.0182(0.5173)
# EVAL: [300/330] Data 0.000 (0.109) Elapsed 1m 1s (remain 0m 5s) Loss: 0.1510(0.5091)
# EVAL: [320/330] Data 0.008 (0.109) Elapsed 1m 5s (remain 0m 1s) Loss: 0.5457(0.5241)
# Epoch 9 - avg_train_loss: 0.5029 avg_val_loss: 0.5230 time: 1021s
# Epoch 9 - Accuracy: 0.8847541294854756
# EVAL: [329/330] Data 0.000 (0.109) Elapsed 1m 7s (remain 0m 0s) Loss: 0.0000(0.5230)
# Epoch: [10][0/1317]Data 1.278 (1.278)Elapsed 0m 2s (remain 49m 25s)Loss: 1.5785(1.5785)Grad: 1.7828
# Epoch: [10][20/1317]Data 0.000 (0.061)Elapsed 0m 16s (remain 17m 7s)Loss: 0.5509(0.5559)Grad: 1.2453
# Epoch: [10][40/1317]Data 0.000 (0.031)Elapsed 0m 31s (remain 16m 6s)Loss: 0.3969(0.5326)Grad: 1.3742
# Epoch: [10][60/1317]Data 0.000 (0.021)Elapsed 0m 45s (remain 15m 39s)Loss: 0.2770(0.5244)Grad: 1.4718
# Epoch: [10][80/1317]Data 0.000 (0.016)Elapsed 0m 59s (remain 15m 14s)Loss: 0.1648(0.5325)Grad: 0.8399
# Epoch: [10][100/1317]Data 0.000 (0.013)Elapsed 1m 14s (remain 14m 57s)Loss: 0.3845(0.5434)Grad: 0.9115
# Epoch: [10][120/1317]Data 0.000 (0.011)Elapsed 1m 28s (remain 14m 38s)Loss: 0.0414(0.5304)Grad: 0.8205
# Epoch: [10][140/1317]Data 0.000 (0.009)Elapsed 1m 43s (remain 14m 22s)Loss: 0.2310(0.5141)Grad: 1.5014
# Epoch: [10][160/1317]Data 0.000 (0.008)Elapsed 1m 57s (remain 14m 5s)Loss: 1.8510(0.5151)Grad: 1.3467
# Epoch: [10][180/1317]Data 0.000 (0.007)Elapsed 2m 12s (remain 13m 51s)Loss: 1.0249(0.5183)Grad: 1.7268
# Epoch: [10][200/1317]Data 0.000 (0.007)Elapsed 2m 26s (remain 13m 35s)Loss: 0.2468(0.5032)Grad: 0.5512
# Epoch: [10][220/1317]Data 0.000 (0.006)Elapsed 2m 41s (remain 13m 19s)Loss: 0.1516(0.5144)Grad: 0.7411
# Epoch: [10][240/1317]Data 0.000 (0.005)Elapsed 2m 56s (remain 13m 6s)Loss: 1.3383(0.5227)Grad: 1.3057
# Epoch: [10][260/1317]Data 0.000 (0.005)Elapsed 3m 10s (remain 12m 50s)Loss: 0.8551(0.5217)Grad: 0.9435
# Epoch: [10][280/1317]Data 0.000 (0.005)Elapsed 3m 24s (remain 12m 35s)Loss: 0.0103(0.5133)Grad: 0.4277
# Epoch: [10][300/1317]Data 0.000 (0.004)Elapsed 3m 39s (remain 12m 20s)Loss: 0.5798(0.5168)Grad: 0.9499
# Epoch: [10][320/1317]Data 0.000 (0.004)Elapsed 3m 53s (remain 12m 5s)Loss: 0.0774(0.5123)Grad: 0.7149
# Epoch: [10][340/1317]Data 0.000 (0.004)Elapsed 4m 8s (remain 11m 50s)Loss: 0.0765(0.5216)Grad: 0.4270
# Epoch: [10][360/1317]Data 0.000 (0.004)Elapsed 4m 23s (remain 11m 36s)Loss: 0.0092(0.5141)Grad: 0.4299
# Epoch: [10][380/1317]Data 0.000 (0.004)Elapsed 4m 37s (remain 11m 21s)Loss: 0.1400(0.5089)Grad: 0.9651
# Epoch: [10][400/1317]Data 0.000 (0.003)Elapsed 4m 51s (remain 11m 6s)Loss: 0.2703(0.5035)Grad: 0.9569
# Epoch: [10][420/1317]Data 0.000 (0.003)Elapsed 5m 6s (remain 10m 52s)Loss: 0.4777(0.4952)Grad: 2.4143
# Epoch: [10][440/1317]Data 0.000 (0.003)Elapsed 5m 20s (remain 10m 37s)Loss: 2.5336(0.5076)Grad: 1.3350
# Epoch: [10][460/1317]Data 0.000 (0.003)Elapsed 5m 35s (remain 10m 22s)Loss: 0.6888(0.5051)Grad: 0.7583
# Epoch: [10][480/1317]Data 0.000 (0.003)Elapsed 5m 49s (remain 10m 7s)Loss: 0.5906(0.5032)Grad: 1.0755
# Epoch: [10][500/1317]Data 0.000 (0.003)Elapsed 6m 4s (remain 9m 53s)Loss: 0.0112(0.5013)Grad: 0.2804
# Epoch: [10][520/1317]Data 0.000 (0.003)Elapsed 6m 18s (remain 9m 38s)Loss: 0.0974(0.4997)Grad: 1.0091
# Epoch: [10][540/1317]Data 0.000 (0.003)Elapsed 6m 33s (remain 9m 23s)Loss: 0.4638(0.4934)Grad: 1.6519
# Epoch: [10][560/1317]Data 0.000 (0.002)Elapsed 6m 47s (remain 9m 9s)Loss: 0.7463(0.4897)Grad: 1.7257
# Epoch: [10][580/1317]Data 0.000 (0.002)Elapsed 7m 1s (remain 8m 54s)Loss: 0.9727(0.4893)Grad: 0.8764
# Epoch: [10][600/1317]Data 0.000 (0.002)Elapsed 7m 16s (remain 8m 39s)Loss: 0.5900(0.4915)Grad: 1.7518
# Epoch: [10][620/1317]Data 0.000 (0.002)Elapsed 7m 30s (remain 8m 25s)Loss: 0.0345(0.4908)Grad: 0.6767
# Epoch: [10][640/1317]Data 0.000 (0.002)Elapsed 7m 45s (remain 8m 10s)Loss: 0.3097(0.4903)Grad: 1.2786
# Epoch: [10][660/1317]Data 0.000 (0.002)Elapsed 7m 59s (remain 7m 55s)Loss: 0.1722(0.4864)Grad: 1.6861
# Epoch: [10][680/1317]Data 0.000 (0.002)Elapsed 8m 14s (remain 7m 41s)Loss: 0.0948(0.4810)Grad: 1.0920
# Epoch: [10][700/1317]Data 0.000 (0.002)Elapsed 8m 28s (remain 7m 26s)Loss: 0.2391(0.4812)Grad: 1.0337
# Epoch: [10][720/1317]Data 0.000 (0.002)Elapsed 8m 43s (remain 7m 12s)Loss: 1.0692(0.4877)Grad: 1.3253
# Epoch: [10][740/1317]Data 0.000 (0.002)Elapsed 8m 57s (remain 6m 57s)Loss: 0.7994(0.4904)Grad: 1.4092
# Epoch: [10][760/1317]Data 0.000 (0.002)Elapsed 9m 12s (remain 6m 43s)Loss: 0.7255(0.4895)Grad: 1.5087
# Epoch: [10][780/1317]Data 0.000 (0.002)Elapsed 9m 26s (remain 6m 28s)Loss: 0.4931(0.4900)Grad: 1.5328
# Epoch: [10][800/1317]Data 0.000 (0.002)Elapsed 9m 40s (remain 6m 14s)Loss: 0.6917(0.4874)Grad: 1.5728
# Epoch: [10][820/1317]Data 0.000 (0.002)Elapsed 9m 55s (remain 5m 59s)Loss: 0.0362(0.4892)Grad: 0.6445
# Epoch: [10][840/1317]Data 0.000 (0.002)Elapsed 10m 9s (remain 5m 45s)Loss: 0.9377(0.4880)Grad: 1.2750
# Epoch: [10][860/1317]Data 0.000 (0.002)Elapsed 10m 24s (remain 5m 30s)Loss: 0.7898(0.4898)Grad: 1.6339
# Epoch: [10][880/1317]Data 0.000 (0.002)Elapsed 10m 38s (remain 5m 16s)Loss: 0.1565(0.4936)Grad: 1.3188
# Epoch: [10][900/1317]Data 0.000 (0.002)Elapsed 10m 53s (remain 5m 1s)Loss: 0.1616(0.4918)Grad: 1.1478
# Epoch: [10][920/1317]Data 0.000 (0.002)Elapsed 11m 7s (remain 4m 47s)Loss: 0.1728(0.4900)Grad: 1.2230
# Epoch: [10][940/1317]Data 0.000 (0.002)Elapsed 11m 22s (remain 4m 32s)Loss: 0.0761(0.4913)Grad: 1.2228
# Epoch: [10][960/1317]Data 0.000 (0.001)Elapsed 11m 36s (remain 4m 18s)Loss: 0.0761(0.4921)Grad: 0.8753
# Epoch: [10][980/1317]Data 0.000 (0.001)Elapsed 11m 51s (remain 4m 3s)Loss: 0.0949(0.4902)Grad: 1.2707
# Epoch: [10][1000/1317]Data 0.000 (0.001)Elapsed 12m 5s (remain 3m 49s)Loss: 0.6037(0.4905)Grad: 0.7384
# Epoch: [10][1020/1317]Data 0.000 (0.001)Elapsed 12m 19s (remain 3m 34s)Loss: 0.0504(0.4884)Grad: 1.1189
# Epoch: [10][1040/1317]Data 0.000 (0.001)Elapsed 12m 34s (remain 3m 19s)Loss: 0.8373(0.4903)Grad: 1.7123
# Epoch: [10][1060/1317]Data 0.000 (0.001)Elapsed 12m 48s (remain 3m 5s)Loss: 1.1525(0.4930)Grad: 1.0106
# Epoch: [10][1080/1317]Data 0.000 (0.001)Elapsed 13m 3s (remain 2m 51s)Loss: 0.0161(0.4909)Grad: 0.5070
# Epoch: [10][1100/1317]Data 0.000 (0.001)Elapsed 13m 17s (remain 2m 36s)Loss: 1.8751(0.4962)Grad: 1.0579
# Epoch: [10][1120/1317]Data 0.000 (0.001)Elapsed 13m 32s (remain 2m 22s)Loss: 1.7780(0.4978)Grad: 1.7148
# Epoch: [10][1140/1317]Data 0.000 (0.001)Elapsed 13m 46s (remain 2m 7s)Loss: 0.4726(0.4966)Grad: 1.1139
# Epoch: [10][1160/1317]Data 0.000 (0.001)Elapsed 14m 1s (remain 1m 53s)Loss: 1.9826(0.4959)Grad: 1.5910
# Epoch: [10][1180/1317]Data 0.000 (0.001)Elapsed 14m 15s (remain 1m 38s)Loss: 0.8826(0.4987)Grad: 1.9181
# Epoch: [10][1200/1317]Data 0.000 (0.001)Elapsed 14m 30s (remain 1m 24s)Loss: 0.5142(0.4997)Grad: 0.7990
# Epoch: [10][1220/1317]Data 0.000 (0.001)Elapsed 14m 44s (remain 1m 9s)Loss: 0.4446(0.4990)Grad: 0.6880
# Epoch: [10][1240/1317]Data 0.000 (0.001)Elapsed 14m 58s (remain 0m 55s)Loss: 0.2988(0.4984)Grad: 1.9331
# Epoch: [10][1260/1317]Data 0.000 (0.001)Elapsed 15m 13s (remain 0m 40s)Loss: 0.4881(0.4970)Grad: 1.1815
# Epoch: [10][1280/1317]Data 0.000 (0.001)Elapsed 15m 27s (remain 0m 26s)Loss: 0.6234(0.4959)Grad: 1.1837
# Epoch: [10][1300/1317]Data 0.000 (0.001)Elapsed 15m 42s (remain 0m 11s)Loss: 0.7667(0.4990)Grad: 0.3771
# Epoch: [10][1316/1317]Data 0.000 (0.001)Elapsed 15m 53s (remain 0m 0s)Loss: 0.9456(0.4991)Grad: 1.6197
# EVAL: [0/330] Data 1.077 (1.077) Elapsed 0m 1s (remain 6m 48s) Loss: 0.3867(0.3867)
# EVAL: [20/330] Data 0.360 (0.141) Elapsed 0m 5s (remain 1m 14s) Loss: 0.4322(0.5315)
# EVAL: [40/330] Data 0.216 (0.117) Elapsed 0m 8s (remain 1m 2s) Loss: 0.3644(0.5641)
# EVAL: [60/330] Data 0.001 (0.115) Elapsed 0m 12s (remain 0m 57s) Loss: 0.3367(0.5593)
# EVAL: [80/330] Data 0.000 (0.119) Elapsed 0m 17s (remain 0m 54s) Loss: 2.1536(0.6589)
# EVAL: [100/330] Data 0.000 (0.114) Elapsed 0m 21s (remain 0m 48s) Loss: 0.5963(0.6147)
# EVAL: [120/330] Data 0.000 (0.117) Elapsed 0m 26s (remain 0m 45s) Loss: 0.5187(0.5866)
# EVAL: [140/330] Data 0.000 (0.114) Elapsed 0m 30s (remain 0m 40s) Loss: 0.3852(0.5748)
# EVAL: [160/330] Data 0.007 (0.111) Elapsed 0m 33s (remain 0m 35s) Loss: 0.1836(0.5677)
# EVAL: [180/330] Data 0.000 (0.111) Elapsed 0m 37s (remain 0m 31s) Loss: 0.2641(0.5560)
# EVAL: [200/330] Data 0.055 (0.110) Elapsed 0m 41s (remain 0m 26s) Loss: 0.0005(0.5467)
# EVAL: [220/330] Data 0.000 (0.111) Elapsed 0m 46s (remain 0m 22s) Loss: 1.2105(0.5449)
# EVAL: [240/330] Data 0.000 (0.112) Elapsed 0m 50s (remain 0m 18s) Loss: 0.4535(0.5266)
# EVAL: [260/330] Data 0.000 (0.111) Elapsed 0m 54s (remain 0m 14s) Loss: 0.6917(0.5181)
# EVAL: [280/330] Data 0.000 (0.110) Elapsed 0m 58s (remain 0m 10s) Loss: 0.0153(0.5282)
# EVAL: [300/330] Data 0.000 (0.109) Elapsed 1m 2s (remain 0m 6s) Loss: 0.2483(0.5204)
# EVAL: [320/330] Data 0.006 (0.108) Elapsed 1m 6s (remain 0m 1s) Loss: 0.5486(0.5364)
# Epoch 10 - avg_train_loss: 0.4991 avg_val_loss: 0.5366 time: 1021s
# Epoch 10 - Accuracy: 0.8847541294854756
# EVAL: [329/330] Data 0.000 (0.107) Elapsed 1m 7s (remain 0m 0s) Loss: 0.0000(0.5366)
# =============== fold: 2 result ================
# Score: 0.88627
# ============ CV ============
# Score: 0.88543
